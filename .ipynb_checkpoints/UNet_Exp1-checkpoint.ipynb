# %% [markdown]
# # UNet

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train && ls

exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val.npy')
exp1_y_val =load(VAL_DIR + '/exp1_y_val.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test.npy')
exp1_y_test =load(TEST_DIR + '/exp1_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FIRM-WEIGHT INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot, num_classes):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', num_classes)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()
    
'''
CALCULATE METRICS
'''
def UNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")

print("Done")
# Out:
# 2023-07-15 00:35:11.370716: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sat Jul 15 00:35:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   24C    P8     8W / 250W |      4MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   31C    P5    17W / 125W |    591MiB /  6144MiB |     30%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train
# exp1_ir_X_train.npy  exp1_rgb_X_train.npy  exp1_y_train.npy
# Done

# %%
'''
MODEL PARAMS
'''
RGB_DIM = (572, 572, 3)
IR_DIM = (572, 572)
ANNOTATION_DIM = (572, 572, 7)

NUM_CLASSES = 7

BATCH_SIZE = 4 #2
EPOCHS = 100  #100

LEARNING_RATE = 1e-4 #1e-4
PATIENCE = 10 #15
FACTOR = 0.1 #0.1

#EXP1_FILENAME = "augmented_unet_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
#    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

EXP1_FILENAME = "unet_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### T/UNet Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def UNet(input_dim):
    '''
    INPUT
    '''
    #inputs = Input((input_dim), name='img')
    inputs = Input((input_dim))
    '''
    CONTRACTION PATH
    '''
    c1, c2, c3, c4, p4 = ContractionPath(inputs)

    '''
    EXPANSION PATH
    '''
    cout = ExpansionPath(c1, c2, c3, c4, p4)

    '''
    OUTPUT
    '''
    outputs = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout)
    outputs = resize(outputs, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs, outputs)

'''
TRAIN
'''
def UNet_Train(model, weights_filename, 
               X_rgb_train, y_train, 
               X_rgb_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
    
            history = model.fit(
                [X_rgb_train], y_train,
                validation_data=([X_rgb_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def UNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test], y_test, verbose=0)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def UNet_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test])
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def UNet_Display(X_rgb_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 3, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("Annotation")
    axes[2].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
    
print("Done")
# Out:
# Done

# %%
exp1_model = UNet(RGB_DIM)

UNet_Train(exp1_model, os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'), 
                exp1_rgb_X_train, exp1_y_train,
                exp1_rgb_X_val, exp1_y_val)
# Out:
# Epoch 1/100
# 2023-07-15 00:38:28.136355: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-07-15 00:38:29.725502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# Epoch 1: val_loss improved from inf to 1.73102, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 38s - loss: 1.8654 - accuracy: 0.2989 - val_loss: 1.7310 - val_accuracy: 0.3634 - lr: 1.0000e-04 - 38s/epoch - 3s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.73102 to 1.70667, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.6364 - accuracy: 0.3022 - val_loss: 1.7067 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.70667 to 1.66905, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5710 - accuracy: 0.3677 - val_loss: 1.6691 - val_accuracy: 0.3176 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.66905 to 1.65342, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5685 - accuracy: 0.3270 - val_loss: 1.6534 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.65342 to 1.64787, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5510 - accuracy: 0.3732 - val_loss: 1.6479 - val_accuracy: 0.2811 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.64787 to 1.63960, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5441 - accuracy: 0.3800 - val_loss: 1.6396 - val_accuracy: 0.2811 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 1.63960
# 14/14 - 17s - loss: 1.5606 - accuracy: 0.2891 - val_loss: 1.6581 - val_accuracy: 0.4110 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 1.63960
# 14/14 - 17s - loss: 1.5460 - accuracy: 0.3737 - val_loss: 1.6520 - val_accuracy: 0.2811 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.63960
# 14/14 - 17s - loss: 1.5493 - accuracy: 0.3845 - val_loss: 1.6430 - val_accuracy: 0.2811 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.63960
# 14/14 - 17s - loss: 1.5317 - accuracy: 0.3845 - val_loss: 1.6420 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 1.63960 to 1.62767, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5342 - accuracy: 0.3813 - val_loss: 1.6277 - val_accuracy: 0.2809 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 1.62767 to 1.62165, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5169 - accuracy: 0.3852 - val_loss: 1.6217 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 1.62165 to 1.61087, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.5101 - accuracy: 0.3940 - val_loss: 1.6109 - val_accuracy: 0.4422 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.61087
# 14/14 - 17s - loss: 1.5021 - accuracy: 0.3756 - val_loss: 1.6193 - val_accuracy: 0.2809 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 1.61087 to 1.53670, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.4861 - accuracy: 0.3955 - val_loss: 1.5367 - val_accuracy: 0.4736 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.53670 to 1.53061, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.4601 - accuracy: 0.3896 - val_loss: 1.5306 - val_accuracy: 0.3697 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 1.53061 to 1.42582, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.4216 - accuracy: 0.4393 - val_loss: 1.4258 - val_accuracy: 0.3729 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 1.42582 to 1.38945, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.3807 - accuracy: 0.4737 - val_loss: 1.3895 - val_accuracy: 0.5512 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 1.38945
# 14/14 - 17s - loss: 1.3713 - accuracy: 0.4590 - val_loss: 1.3987 - val_accuracy: 0.4555 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 1.38945
# 14/14 - 17s - loss: 1.3786 - accuracy: 0.4536 - val_loss: 1.4864 - val_accuracy: 0.3150 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 1.38945 to 1.32560, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.3951 - accuracy: 0.4045 - val_loss: 1.3256 - val_accuracy: 0.5861 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 1.32560
# 14/14 - 17s - loss: 1.3291 - accuracy: 0.4861 - val_loss: 1.3568 - val_accuracy: 0.4954 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 1.32560 to 1.29251, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.3047 - accuracy: 0.5036 - val_loss: 1.2925 - val_accuracy: 0.5764 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 1.29251 to 1.29039, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.2736 - accuracy: 0.5288 - val_loss: 1.2904 - val_accuracy: 0.5296 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 1.29039
# 14/14 - 17s - loss: 1.2850 - accuracy: 0.5090 - val_loss: 1.7348 - val_accuracy: 0.2424 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 1.29039 to 1.28498, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.3046 - accuracy: 0.5091 - val_loss: 1.2850 - val_accuracy: 0.5757 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 1.28498
# 14/14 - 17s - loss: 1.3946 - accuracy: 0.4454 - val_loss: 1.5766 - val_accuracy: 0.2898 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 1.28498
# 14/14 - 17s - loss: 1.4265 - accuracy: 0.4469 - val_loss: 1.4459 - val_accuracy: 0.3594 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 1.28498 to 1.26556, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.3301 - accuracy: 0.4912 - val_loss: 1.2656 - val_accuracy: 0.5612 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 1.26556
# 14/14 - 17s - loss: 1.2870 - accuracy: 0.5107 - val_loss: 1.3713 - val_accuracy: 0.4021 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 1.26556
# 14/14 - 17s - loss: 1.3024 - accuracy: 0.5045 - val_loss: 1.6824 - val_accuracy: 0.2545 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 1.26556
# 14/14 - 17s - loss: 1.3327 - accuracy: 0.4796 - val_loss: 1.4487 - val_accuracy: 0.3700 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 1.26556
# 14/14 - 17s - loss: 1.3227 - accuracy: 0.4609 - val_loss: 1.3820 - val_accuracy: 0.4286 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 1.26556
# 14/14 - 17s - loss: 1.2878 - accuracy: 0.4986 - val_loss: 1.3098 - val_accuracy: 0.4980 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 1.26556 to 1.23588, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.2746 - accuracy: 0.4980 - val_loss: 1.2359 - val_accuracy: 0.5969 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 1.23588 to 1.23284, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.2541 - accuracy: 0.5088 - val_loss: 1.2328 - val_accuracy: 0.5912 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 1.23284
# 14/14 - 17s - loss: 1.2594 - accuracy: 0.5040 - val_loss: 1.2570 - val_accuracy: 0.5370 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 1.23284
# 14/14 - 17s - loss: 1.2643 - accuracy: 0.4949 - val_loss: 1.3603 - val_accuracy: 0.4280 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 1.23284
# 14/14 - 17s - loss: 1.3137 - accuracy: 0.4584 - val_loss: 1.4221 - val_accuracy: 0.3438 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 1.23284
# 14/14 - 17s - loss: 1.2956 - accuracy: 0.4843 - val_loss: 1.2767 - val_accuracy: 0.5220 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 1.23284
# 14/14 - 17s - loss: 1.2267 - accuracy: 0.5347 - val_loss: 1.2330 - val_accuracy: 0.5618 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 1.23284 to 1.22438, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.2010 - accuracy: 0.5451 - val_loss: 1.2244 - val_accuracy: 0.5664 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 1.22438
# 14/14 - 17s - loss: 1.2124 - accuracy: 0.5327 - val_loss: 1.2562 - val_accuracy: 0.5572 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 1.22438 to 1.19380, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.2220 - accuracy: 0.5114 - val_loss: 1.1938 - val_accuracy: 0.5802 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 1.19380
# 14/14 - 17s - loss: 1.1921 - accuracy: 0.5371 - val_loss: 1.2213 - val_accuracy: 0.5669 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 1.19380
# 14/14 - 17s - loss: 1.1964 - accuracy: 0.5356 - val_loss: 1.1982 - val_accuracy: 0.5679 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 1.19380
# 14/14 - 17s - loss: 1.1679 - accuracy: 0.5459 - val_loss: 1.5026 - val_accuracy: 0.3418 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 1.19380 to 1.11915, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.1739 - accuracy: 0.5551 - val_loss: 1.1191 - val_accuracy: 0.6036 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 1.11915
# 14/14 - 17s - loss: 1.3170 - accuracy: 0.4434 - val_loss: 1.2047 - val_accuracy: 0.5901 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 1.11915
# 14/14 - 17s - loss: 1.2083 - accuracy: 0.5230 - val_loss: 1.2055 - val_accuracy: 0.5422 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 1.11915
# 14/14 - 17s - loss: 1.1512 - accuracy: 0.5523 - val_loss: 1.1359 - val_accuracy: 0.5998 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 1.11915
# 14/14 - 17s - loss: 1.1567 - accuracy: 0.5414 - val_loss: 1.2046 - val_accuracy: 0.5877 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 53/100
#
# Epoch 53: val_loss improved from 1.11915 to 1.10049, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.1226 - accuracy: 0.5650 - val_loss: 1.1005 - val_accuracy: 0.6051 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 1.10049
# 14/14 - 17s - loss: 1.1070 - accuracy: 0.5842 - val_loss: 1.1208 - val_accuracy: 0.5783 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 1.10049
# 14/14 - 17s - loss: 1.1007 - accuracy: 0.5519 - val_loss: 1.1259 - val_accuracy: 0.5671 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 56/100
#
# Epoch 56: val_loss improved from 1.10049 to 1.05155, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.1193 - accuracy: 0.5591 - val_loss: 1.0515 - val_accuracy: 0.6041 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 1.05155
# 14/14 - 17s - loss: 1.0855 - accuracy: 0.5615 - val_loss: 1.2291 - val_accuracy: 0.4705 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 1.05155
# 14/14 - 17s - loss: 1.1064 - accuracy: 0.5478 - val_loss: 1.0644 - val_accuracy: 0.5682 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 1.05155
# 14/14 - 17s - loss: 1.0693 - accuracy: 0.5518 - val_loss: 1.0905 - val_accuracy: 0.5655 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 60/100
#
# Epoch 60: val_loss improved from 1.05155 to 1.03654, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.0208 - accuracy: 0.5695 - val_loss: 1.0365 - val_accuracy: 0.6032 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 1.03654 to 1.01664, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.0105 - accuracy: 0.5876 - val_loss: 1.0166 - val_accuracy: 0.6012 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 1.01664
# 14/14 - 17s - loss: 1.0028 - accuracy: 0.5808 - val_loss: 1.0367 - val_accuracy: 0.6021 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 1.01664
# 14/14 - 17s - loss: 1.1126 - accuracy: 0.5448 - val_loss: 1.1880 - val_accuracy: 0.4800 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 1.01664
# 14/14 - 17s - loss: 1.0876 - accuracy: 0.5650 - val_loss: 1.1269 - val_accuracy: 0.6010 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 1.01664
# 14/14 - 17s - loss: 1.1228 - accuracy: 0.5349 - val_loss: 1.2600 - val_accuracy: 0.5595 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 1.01664 to 0.97143, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.0569 - accuracy: 0.5695 - val_loss: 0.9714 - val_accuracy: 0.6349 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 67/100
#
# Epoch 67: val_loss improved from 0.97143 to 0.96185, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.9813 - accuracy: 0.5943 - val_loss: 0.9618 - val_accuracy: 0.6174 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.96185
# 14/14 - 17s - loss: 0.9881 - accuracy: 0.5934 - val_loss: 1.1607 - val_accuracy: 0.5239 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.96185
# 14/14 - 17s - loss: 1.0486 - accuracy: 0.5804 - val_loss: 1.0067 - val_accuracy: 0.6212 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.96185
# 14/14 - 17s - loss: 0.9935 - accuracy: 0.5936 - val_loss: 1.0499 - val_accuracy: 0.5531 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.96185
# 14/14 - 17s - loss: 0.9321 - accuracy: 0.6203 - val_loss: 0.9650 - val_accuracy: 0.6260 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.96185
# 14/14 - 17s - loss: 0.9168 - accuracy: 0.6224 - val_loss: 1.1365 - val_accuracy: 0.5097 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 73/100
#
# Epoch 73: val_loss improved from 0.96185 to 0.95349, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 1.0238 - accuracy: 0.5684 - val_loss: 0.9535 - val_accuracy: 0.6211 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.95349
# 14/14 - 17s - loss: 0.9664 - accuracy: 0.5964 - val_loss: 1.1160 - val_accuracy: 0.5071 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.95349
# 14/14 - 17s - loss: 0.9578 - accuracy: 0.6016 - val_loss: 1.0251 - val_accuracy: 0.6134 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 76/100
#
# Epoch 76: val_loss improved from 0.95349 to 0.90300, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.9247 - accuracy: 0.6260 - val_loss: 0.9030 - val_accuracy: 0.6462 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.90300
# 14/14 - 17s - loss: 0.8805 - accuracy: 0.6433 - val_loss: 0.9531 - val_accuracy: 0.6219 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.90300
# 14/14 - 17s - loss: 0.8827 - accuracy: 0.6305 - val_loss: 0.9969 - val_accuracy: 0.5942 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.90300
# 14/14 - 17s - loss: 0.8616 - accuracy: 0.6415 - val_loss: 0.9050 - val_accuracy: 0.6425 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.90300
# 14/14 - 17s - loss: 0.9065 - accuracy: 0.6209 - val_loss: 1.0036 - val_accuracy: 0.5916 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.90300 to 0.88867, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.8844 - accuracy: 0.6378 - val_loss: 0.8887 - val_accuracy: 0.6408 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.88867
# 14/14 - 17s - loss: 0.9788 - accuracy: 0.5945 - val_loss: 0.9394 - val_accuracy: 0.6262 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.88867
# 14/14 - 17s - loss: 0.8994 - accuracy: 0.6317 - val_loss: 1.0420 - val_accuracy: 0.6211 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.88867
# 14/14 - 17s - loss: 0.9056 - accuracy: 0.6210 - val_loss: 0.9054 - val_accuracy: 0.6420 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.88867
# 14/14 - 17s - loss: 0.8267 - accuracy: 0.6637 - val_loss: 0.9508 - val_accuracy: 0.5997 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 86/100
#
# Epoch 86: val_loss improved from 0.88867 to 0.88449, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.8349 - accuracy: 0.6656 - val_loss: 0.8845 - val_accuracy: 0.6510 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.88449
# 14/14 - 17s - loss: 0.7874 - accuracy: 0.6835 - val_loss: 0.9290 - val_accuracy: 0.6291 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.88449
# 14/14 - 17s - loss: 0.8234 - accuracy: 0.6792 - val_loss: 0.9137 - val_accuracy: 0.6399 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.88449
# 14/14 - 17s - loss: 0.8023 - accuracy: 0.6761 - val_loss: 0.9830 - val_accuracy: 0.5805 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.88449
# 14/14 - 17s - loss: 0.8332 - accuracy: 0.6631 - val_loss: 0.9426 - val_accuracy: 0.6131 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 91/100
#
# Epoch 91: val_loss improved from 0.88449 to 0.85671, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.7718 - accuracy: 0.6960 - val_loss: 0.8567 - val_accuracy: 0.6544 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.85671
# 14/14 - 17s - loss: 0.8806 - accuracy: 0.6615 - val_loss: 1.2094 - val_accuracy: 0.4689 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 93/100
#
# Epoch 93: val_loss improved from 0.85671 to 0.85598, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 14/14 - 18s - loss: 0.9345 - accuracy: 0.6061 - val_loss: 0.8560 - val_accuracy: 0.6616 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.8291 - accuracy: 0.6602 - val_loss: 0.9390 - val_accuracy: 0.6342 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.7988 - accuracy: 0.6859 - val_loss: 0.9261 - val_accuracy: 0.6577 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.7923 - accuracy: 0.6819 - val_loss: 0.9058 - val_accuracy: 0.6290 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.8395 - accuracy: 0.6679 - val_loss: 1.0454 - val_accuracy: 0.5695 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.8921 - accuracy: 0.6415 - val_loss: 0.9137 - val_accuracy: 0.6352 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.8232 - accuracy: 0.6678 - val_loss: 0.9895 - val_accuracy: 0.6117 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.85598
# 14/14 - 17s - loss: 0.8074 - accuracy: 0.6803 - val_loss: 0.8841 - val_accuracy: 0.6621 - lr: 1.0000e-04 - 17s/epoch - 1s/step

# %%
score = UNet_Score(
    exp1_model, 
    os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'),
    exp1_rgb_X_test,
    exp1_y_test)
# Out:
# Test loss: 0.8385204076766968
# Test accuracy: 0.6828432679176331

# %%
y_pred = UNet_Predict(exp1_model, exp1_rgb_X_test)

# %%
UNet_Display(exp1_rgb_X_test, exp1_y_test, y_pred)

# %%
UNet_Metrics(exp1_y_test, y_pred, os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'))
