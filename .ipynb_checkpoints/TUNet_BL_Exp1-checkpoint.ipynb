# %% [markdown]
# # UNet

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed/Experiment1/Train && ls

exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val.npy')
exp1_y_val =load(VAL_DIR + '/exp1_y_val.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test.npy')
exp1_y_test =load(TEST_DIR + '/exp1_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FIRM-WEIGHT INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot, num_classes):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', num_classes)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# Fri Jul 14 02:22:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   40C    P0    50W / 250W |  24235MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   36C    P5    17W / 125W |   4953MiB /  6144MiB |     34%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train
# exp1_ir_X_train.npy  exp1_rgb_X_train.npy  exp1_y_train.npy
# Done

# %%
'''
MODEL PARAMS
'''
RGB_DIM = (572, 572, 3)
IR_DIM = (572, 572)
ANNOTATION_DIM = (572, 572, 7)

NUM_CLASSES = 7

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

EXP1_FILENAME = "augmented_unet_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### T/UNet Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def UNet(input_dim):
    '''
    INPUT
    '''
    #inputs = Input((input_dim), name='img')
    inputs = Input((input_dim))
    '''
    CONTRACTION PATH
    '''
    c1, c2, c3, c4, p4 = ContractionPath(inputs)

    '''
    EXPANSION PATH
    '''
    cout = ExpansionPath(c1, c2, c3, c4, p4)

    '''
    OUTPUT
    '''
    outputs = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout)
    outputs = resize(outputs, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs, outputs)

'''
TRAIN
'''
def UNet_Train(model, weights_filename, 
               X_rgb_train, y_train, 
               X_rgb_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
    
            history = model.fit(
                [X_rgb_train], y_train,
                validation_data=([X_rgb_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def UNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test], y_test, verbose=0)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def UNet_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test])
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def UNet_Display(X_rgb_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 3, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("Annotation")
    axes[2].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
        
'''
CALCULATE METRICS
'''
def UNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)
    
    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    
print("Done")
# Out:
# Done

# %%
exp1_model = UNet(RGB_DIM)

start_time = time.time()

UNet_Train(exp1_model, os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'), 
                exp1_rgb_X_train, exp1_y_train,
                exp1_rgb_X_val, exp1_y_val)

end_time = time.time()

elapsed_time = end_time - start_time

print("Elapsed time: " + repr(elapsed_time))
print("Done")
# Out:
# Epoch 1/1000
# 2023-07-14 02:23:17.127625: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_12/dropout_103/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# Epoch 1: val_loss improved from inf to 1.77164, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 23s - loss: 1.8205 - accuracy: 0.3218 - val_loss: 1.7716 - val_accuracy: 0.2852 - lr: 1.0000e-04 - 23s/epoch - 818ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 1.77164 to 1.66271, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5827 - accuracy: 0.3474 - val_loss: 1.6627 - val_accuracy: 0.2804 - lr: 1.0000e-04 - 22s/epoch - 775ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 1.66271 to 1.65561, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5659 - accuracy: 0.3718 - val_loss: 1.6556 - val_accuracy: 0.2803 - lr: 1.0000e-04 - 22s/epoch - 774ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 1.65561 to 1.64380, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 -
- lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 1.22697
# 28/28 - 21s - loss: 1.2426 - accuracy: 0.5079 - val_loss: 1.2473 - val_accuracy: 0.5304 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 1.22697 to 1.19320, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1845 - accuracy: 0.5257 - val_loss: 1.1932 - val_accuracy: 0.5816 - lr: 1.0000e-04 - 22s/epoch - 775ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 1.19320
# 28/28 - 21s - loss: 1.1643 - accuracy: 0.5296 - val_loss: 1.2049 - val_accuracy: 0.5741 - lr: 1.0000e-04 - 21s/epoch - 747ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss improved from 1.19320 to 1.10466, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1650 - accuracy: 0.5350 - val_loss: 1.1047 - val_accuracy: 0.6101 - lr: 1.0000e-04 - 22s/epoch - 771ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 1.10466
# 28/28 - 21s - loss: 1.1456 - accuracy: 0.5127 - val_loss: 1.1492 - val_accuracy: 0.4958 - lr: 1.0000e-04 - 21s/epoch - 750ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 1.10466
# 28/28 - 21s - loss: 1.1176 - accuracy: 0.5447 - val_loss: 1.2938 - val_accuracy: 0.3813 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 1.10466
# 28/28 - 21s - loss: 1.1257 - accuracy: 0.5344 - val_loss: 1.1405 - val_accuracy: 0.5794 - lr: 1.0000e-04 - 21s/epoch - 742ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 1.10466 to 1.07509, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1344 - accuracy: 0.5277 - val_loss: 1.0751 - val_accuracy: 0.5764 - lr: 1.0000e-04 - 22s/epoch - 774ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 1.07509
# 28/28 - 21s - loss: 1.1019 - accuracy: 0.5501 - val_loss: 1.1008 - val_accuracy: 0.5654 - lr: 1.0000e-04 - 21s/epoch - 747ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 1.07509
# 28/28 - 21s - loss: 1.0975 - accuracy: 0.5445 - val_loss: 1.2507 - val_accuracy: 0.4146 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss improved from 1.07509 to 1.03547, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0600 - accuracy: 0.5452 - val_loss: 1.0355 - val_accuracy: 0.5812 - lr: 1.0000e-04 - 22s/epoch - 771ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss improved from 1.03547 to 0.98064, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0403 - accuracy: 0.5523 - val_loss: 0.9806 - val_accuracy: 0.6290 - lr: 1.0000e-04 - 22s/epoch - 771ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 0.98064
# 28/28 - 21s - loss: 1.0128 - accuracy: 0.5732 - val_loss: 1.1194 - val_accuracy: 0.6076 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.98064
# 28/28 - 21s - loss: 0.9856 - accuracy: 0.5810 - val_loss: 1.1372 - val_accuracy: 0.4764 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.98064
# 28/28 - 21s - loss: 1.1895 - accuracy: 0.5466 - val_loss: 1.1072 - val_accuracy: 0.5665 - lr: 1.0000e-04 - 21s/epoch - 745ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.98064
# 28/28 - 21s - loss: 1.0971 - accuracy: 0.5239 - val_loss: 1.0686 - val_accuracy: 0.5943 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss improved from 0.98064 to 0.96624, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0205 - accuracy: 0.5709 - val_loss: 0.9662 - val_accuracy: 0.6151 - lr: 1.0000e-04 - 22s/epoch - 771ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 0.96624
# 28/28 - 21s - loss: 1.0356 - accuracy: 0.5809 - val_loss: 1.1825 - val_accuracy: 0.4131 - lr: 1.0000e-04 - 21s/epoch - 749ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 0.96624
# 28/28 - 21s - loss: 1.0217 - accuracy: 0.5593 - val_loss: 1.0997 - val_accuracy: 0.6067 - lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 0.96624
# 28/28 - 21s - loss: 1.0760 - accuracy: 0.5453 - val_loss: 1.0604 - val_accuracy: 0.6065 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss improved from 0.96624 to 0.94398, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 0
- lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 0.78024
# 28/28 - 21s - loss: 0.6912 - accuracy: 0.7242 - val_loss: 0.9192 - val_accuracy: 0.6305 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 0.78024
# 28/28 - 21s - loss: 0.6806 - accuracy: 0.7491 - val_loss: 0.8393 - val_accuracy: 0.6740 - lr: 1.0000e-04 - 21s/epoch - 745ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss improved from 0.78024 to 0.77181, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_unet_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 21s - loss: 0.6725 - accuracy: 0.7409 - val_loss: 0.7718 - val_accuracy: 0.7015 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6780 - accuracy: 0.7411 - val_loss: 0.8475 - val_accuracy: 0.6522 - lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6517 - accuracy: 0.7499 - val_loss: 0.8685 - val_accuracy: 0.6897 - lr: 1.0000e-04 - 21s/epoch - 745ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6604 - accuracy: 0.7589 - val_loss: 0.8559 - val_accuracy: 0.6828 - lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6344 - accuracy: 0.7665 - val_loss: 0.9744 - val_accuracy: 0.6582 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6439 - accuracy: 0.7572 - val_loss: 0.8074 - val_accuracy: 0.6741 - lr: 1.0000e-04 - 21s/epoch - 742ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6518 - accuracy: 0.7584 - val_loss: 0.8637 - val_accuracy: 0.6716 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6166 - accuracy: 0.7748 - val_loss: 0.9227 - val_accuracy: 0.6651 - lr: 1.0000e-04 - 21s/epoch - 743ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6055 - accuracy: 0.7759 - val_loss: 0.8798 - val_accuracy: 0.6625 - lr: 1.0000e-04 - 21s/epoch - 742ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6744 - accuracy: 0.7428 - val_loss: 0.9058 - val_accuracy: 0.6648 - lr: 1.0000e-04 - 21s/epoch - 747ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6429 - accuracy: 0.7520 - val_loss: 0.9253 - val_accuracy: 0.6824 - lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6376 - accuracy: 0.7686 - val_loss: 0.8270 - val_accuracy: 0.6619 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.5609 - accuracy: 0.7958 - val_loss: 0.8082 - val_accuracy: 0.6774 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.6379 - accuracy: 0.7590 - val_loss: 0.7963 - val_accuracy: 0.6879 - lr: 1.0000e-04 - 21s/epoch - 745ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.5952 - accuracy: 0.7785 - val_loss: 0.8256 - val_accuracy: 0.6867 - lr: 1.0000e-04 - 21s/epoch - 746ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 0.77181
# 28/28 - 21s - loss: 0.5082 - accuracy: 0.8192 - val_loss: 0.9152 - val_accuracy: 0.6836 - lr: 1.0000e-04 - 21s/epoch - 744ms/step
# Epoch 89: early stopping
# Elapsed time: 1879.8563945293427
# Done

# %%
score = UNet_Score(
    exp1_model, 
    os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'),
    exp1_rgb_X_test,
    exp1_y_test)
# Out:
# Test loss: 0.6818190813064575
# Test accuracy: 0.7421025037765503

# %%
y_pred = UNet_Predict(exp1_model, exp1_rgb_X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
UNet_Display(exp1_rgb_X_test, exp1_y_test, y_pred)

# %%
UNet_Metrics(exp1_y_test, y_pred, os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'))
# Out:
# Mean IoU: 0.47567663240839486
# Pixel accuracy: 0.7421025216042698
# Mean accuracy: 0.6269932094692087
# Frequency-Weighted IoU: 0.7293476570407681
