# %% [markdown]
# # TUNet BL

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train && ls

exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val.npy')
exp1_y_val =load(VAL_DIR + '/exp1_y_val.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test.npy')
exp1_y_test =load(TEST_DIR + '/exp1_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FIRM-WEIGHT INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot, num_classes):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', num_classes)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-07-15 18:17:38.799062: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sat Jul 15 18:17:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   25C    P8     8W / 250W |      4MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   31C    P5    17W / 125W |    484MiB /  6144MiB |     27%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train
# exp1_ir_X_train.npy  exp1_rgb_X_train.npy  exp1_y_train.npy
# Done

# %%
'''
MODEL PARAMS
'''
RGB_DIM = (572, 572, 3)
IR_DIM = (572, 572)
ANNOTATION_DIM = (572, 572, 7)
CAT_DIM = (572, 572, 4)

NUM_CLASSES = 7

BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

EXP1_FILENAME = "augmented_tunet_bl_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### TUNet BL Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def TUNet_BL():
    '''
    INPUT
    '''
    # Expected inputs are an RGB and an IR image
    input_rgb = Input((572, 572, 3))
    input_ir = Input((572, 572))
    
    # Concatenate for bottom layer input
    input_ir = tf.expand_dims(input_ir, axis=-1)
    cat_input = tf.concat([input_rgb, input_ir], axis=-1)
    
    '''
    CONTRACTION PATH
    '''
    c1, c2, c3, c4, p4 = ContractionPath(cat_input)

    '''
    EXPANSION PATH
    '''
    cout = ExpansionPath(c1, c2, c3, c4, p4)

    '''
    OUTPUT
    '''
    softmax_output = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout)
    softmax_output = resize(softmax_output, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs=[input_rgb, input_ir], outputs=softmax_output)

'''
TRAIN
'''
def TUNet_Train(model, weights_filename, 
               X_rgb_train, X_ir_train, y_train, 
               X_rgb_val, X_ir_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
    
            history = model.fit(
                [X_rgb_train, X_ir_train], y_train,
                validation_data=([X_rgb_val, X_ir_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def TUNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, X_ir_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test, X_ir_test], y_test, verbose=0)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def TUNet_Predict(model, X_rgb_test, X_ir_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test, X_ir_test])
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def TUNet_Display(X_rgb_test, X_ir_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 4, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(X_ir_test[n], cmap='gray')
    axes[2].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[3].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("IR")
    axes[2].set_title("Annotation")
    axes[3].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
        
'''
CALCULATE METRICS
'''
def TUNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)
    
    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    
print("Done")
# Out:
# Done

# %%
exp1_model = TUNet_BL()

# %%
TUNet_Train(exp1_model, os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'), 
                exp1_rgb_X_train, exp1_ir_X_train, exp1_y_train,
                exp1_rgb_X_val, exp1_ir_X_val, exp1_y_val)

print("Done")
# Out:
# Epoch 1/1000
# 2023-07-15 18:26:18.538266: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_16/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-07-15 18:26:20.249894: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# Epoch 1: val_loss improved from inf to 1.71931, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 36s - loss: 1.7267 - accuracy: 0.3561 - val_loss: 1.7193 - val_accuracy: 0.2807 - lr: 1.0000e-04 - 36s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 1.71931 to 1.66218, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5618 - accuracy: 0.3690 - val_loss: 1.6622 - val_accuracy: 0.2874 - lr: 1.0000e-04 - 22s/epoch - 789ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 1.66218
# 28/28 - 22s - loss: 1.5566 - accuracy: 0.3605 - val_loss: 1.6718 - val_accuracy: 0.2809 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 1.66218 to 1.64490, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5260 - accuracy: 0.3855 - val_loss: 1.6449 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 22s/epoch - 795ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 1.64490 to 1.63869, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5354 - accuracy: 0.3462 - val_loss: 1.6387 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 22s/epoch - 795ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 1.63869
# 28/28 - 22s - loss: 1.5100 - accuracy: 0.3481 - val_loss: 1.6501 - val_accuracy: 0.2809 - lr: 1.0000e-04 - 22s/epoch - 770ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 1.63869 to 1.60942, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.5109 - accuracy: 0.3886 - val_loss: 1.6094 - val_accuracy: 0.2898 - lr: 1.0000e-04 - 22s/epoch - 793ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 1.60942 to 1.52985, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.4592 - accuracy: 0.3721 - val_loss: 1.5298 - val_accuracy: 0.3021 - lr: 1.0000e-04 - 22s/epoch - 795ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 1.52985
# 28/28 - 22s - loss: 1.4300 - accuracy: 0.3999 - val_loss: 1.5410 - val_accuracy: 0.2997 - lr: 1.0000e-04 - 22s/epoch - 769ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 1.52985 to 1.51930, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.4015 - accuracy: 0.4135 - val_loss: 1.5193 - val_accuracy: 0.3028 - lr: 1.0000e-04 - 22s/epoch - 796ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 1.51930 to 1.41744, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.3735 - accuracy: 0.3876 - val_loss: 1.4174 - val_accuracy: 0.4072 - lr: 1.0000e-04 - 22s/epoch - 793ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 1.41744 to 1.38224, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.3317 - accuracy: 0.4434 - val_loss: 1.3822 - val_accuracy: 0.4390 - lr: 1.0000e-04 - 22s/epoch - 797ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 1.38224
# 28/28 - 22s - loss: 1.3231 - accuracy: 0.4352 - val_loss: 1.4085 - val_accuracy: 0.4355 - lr: 1.0000e-04 - 22s/epoch - 770ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 1.38224 to 1.36012, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.2812 - accuracy: 0.4526 - val_loss: 1.3601 - val_accuracy: 0.4480 - lr: 1.0000e-04 - 22s/epoch - 794ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss improved from 1.36012 to 1.33399, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.3080 - accuracy: 0.4371 - val_loss: 1.3340 - val_accuracy: 0.4913 - lr: 1.0000e-04 - 22s/epoch - 793ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss improved from 1.33399 to 1.31492, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.2287 - accuracy: 0.4758 - val_loss: 1.3149 - val_accuracy: 0.5144 - lr: 1.0000e-04 - 22s/epoch - 792ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 1.31492
# 28/28 - 22s - loss: 1.2246 - accuracy: 0.4879 - val_loss: 1.3366 - val_accuracy: 0.4994 - lr: 1.0000e-04 - 22s/epoch - 769ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 1.31492
# 28/28 - 22s - loss: 1.2001 - accuracy: 0.4937 - val_loss: 1.3648 - val_accuracy: 0.5071 - lr: 1.0000e-04 - 22s/epoch - 770ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss improved from 1.31492 to 1.27259, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.2391 - accuracy: 0.4514 - val_loss: 1.2726 - val_accuracy: 0.5113 - lr: 1.0000e-04 - 22s/epoch - 796ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 1.27259
# 28/28 - 22s - loss: 1.1991 - accuracy: 0.5058 - val_loss: 1.4091 - val_accuracy: 0.4006 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss improved from 1.27259 to 1.22279, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.2156 - accuracy: 0.4730 - val_loss: 1.2228 - val_accuracy: 0.5331 - lr: 1.0000e-04 - 22s/epoch - 793ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 1.22279
# 28/28 - 22s - loss: 1.1865 - accuracy: 0.4814 - val_loss: 1.2653 - val_accuracy: 0.5318 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 1.22279 to 1.20084, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1754 - accuracy: 0.5133 - val_loss: 1.2008 - val_accuracy: 0.5414 - lr: 1.0000e-04 - 22s/epoch - 799ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 1.20084 to 1.19947, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1397 - accuracy: 0.5176 - val_loss: 1.1995 - val_accuracy: 0.5439 - lr: 1.0000e-04 - 22s/epoch - 793ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 1.19947
# 28/28 - 22s - loss: 1.1288 - accuracy: 0.5122 - val_loss: 1.2859 - val_accuracy: 0.5321 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 1.19947
# 28/28 - 22s - loss: 1.1898 - accuracy: 0.5202 - val_loss: 1.2035 - val_accuracy: 0.5543 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss improved from 1.19947 to 1.18935, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1512 - accuracy: 0.5043 - val_loss: 1.1894 - val_accuracy: 0.5535 - lr: 1.0000e-04 - 22s/epoch - 790ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 1.18935 to 1.16498, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.1275 - accuracy: 0.5102 - val_loss: 1.1650 - val_accuracy: 0.5604 - lr: 1.0000e-04 - 22s/epoch - 796ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 1.16498
# 28/28 - 22s - loss: 1.1201 - accuracy: 0.5319 - val_loss: 1.2659 - val_accuracy: 0.5126 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 1.16498
# 28/28 - 22s - loss: 1.1196 - accuracy: 0.5207 - val_loss: 1.2752 - val_accuracy: 0.5075 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 1.16498
# 28/28 - 21s - loss: 1.1167 - accuracy: 0.5370 - val_loss: 1.2280 - val_accuracy: 0.5486 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 1.16498
# 28/28 - 22s - loss: 1.0988 - accuracy: 0.5432 - val_loss: 1.2710 - val_accuracy: 0.5193 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 1.16498
# 28/28 - 21s - loss: 1.2130 - accuracy: 0.4615 - val_loss: 1.2014 - val_accuracy: 0.5157 - lr: 1.0000e-04 - 21s/epoch - 768ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 1.16498 to 1.13391, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0844 - accuracy: 0.5311 - val_loss: 1.1339 - val_accuracy: 0.5742 - lr: 1.0000e-04 - 22s/epoch - 792ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 1.13391
# 28/28 - 22s - loss: 1.0705 - accuracy: 0.5436 - val_loss: 1.2124 - val_accuracy: 0.5439 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss improved from 1.13391 to 1.11104, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0652 - accuracy: 0.5507 - val_loss: 1.1110 - val_accuracy: 0.5850 - lr: 1.0000e-04 - 22s/epoch - 799ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 1.11104
# 28/28 - 21s - loss: 1.0945 - accuracy: 0.5487 - val_loss: 1.2886 - val_accuracy: 0.5362 - lr: 1.0000e-04 - 21s/epoch - 768ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 1.11104
# 28/28 - 22s - loss: 1.1378 - accuracy: 0.5567 - val_loss: 1.2560 - val_accuracy: 0.5230 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 1.11104
# 28/28 - 21s - loss: 1.1824 - accuracy: 0.4927 - val_loss: 1.1229 - val_accuracy: 0.5923 - lr: 1.0000e-04 - 21s/epoch - 768ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 1.11104
# 28/28 - 21s - loss: 1.1128 - accuracy: 0.4983 - val_loss: 1.2503 - val_accuracy: 0.5435 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 1.11104
# 28/28 - 22s - loss: 1.0680 - accuracy: 0.5507 - val_loss: 1.1371 - val_accuracy: 0.5753 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss improved from 1.11104 to 1.04456, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0312 - accuracy: 0.5727 - val_loss: 1.0446 - val_accuracy: 0.6155 - lr: 1.0000e-04 - 22s/epoch - 801ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss improved from 1.04456 to 1.02224, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0355 - accuracy: 0.5652 - val_loss: 1.0222 - val_accuracy: 0.6172 - lr: 1.0000e-04 - 22s/epoch - 796ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 1.02224
# 28/28 - 21s - loss: 1.0268 - accuracy: 0.5794 - val_loss: 1.1601 - val_accuracy: 0.5708 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 1.02224
# 28/28 - 22s - loss: 1.0293 - accuracy: 0.5716 - val_loss: 1.0493 - val_accuracy: 0.5998 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 1.02224
# 28/28 - 22s - loss: 1.1255 - accuracy: 0.5319 - val_loss: 1.0962 - val_accuracy: 0.6137 - lr: 1.0000e-04 - 22s/epoch - 769ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 1.02224
# 28/28 - 22s - loss: 1.0244 - accuracy: 0.5800 - val_loss: 1.0971 - val_accuracy: 0.6090 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss improved from 1.02224 to 1.02203, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0301 - accuracy: 0.5423 - val_loss: 1.0220 - val_accuracy: 0.6160 - lr: 1.0000e-04 - 22s/epoch - 797ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss improved from 1.02203 to 0.98624, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 1.0254 - accuracy: 0.5580 - val_loss: 0.9862 - val_accuracy: 0.6359 - lr: 1.0000e-04 - 22s/epoch - 791ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 0.98624
# 28/28 - 21s - loss: 1.0124 - accuracy: 0.5917 - val_loss: 1.1506 - val_accuracy: 0.5504 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 0.98624
# 28/28 - 21s - loss: 0.9876 - accuracy: 0.5940 - val_loss: 0.9974 - val_accuracy: 0.6486 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 0.98624
# 28/28 - 21s - loss: 0.9808 - accuracy: 0.6008 - val_loss: 1.0626 - val_accuracy: 0.5934 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss improved from 0.98624 to 0.91721, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 0.9200 - accuracy: 0.6223 - val_loss: 0.9172 - val_accuracy: 0.6744 - lr: 1.0000e-04 - 22s/epoch - 794ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9632 - accuracy: 0.6084 - val_loss: 0.9235 - val_accuracy: 0.6695 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9133 - accuracy: 0.6167 - val_loss: 0.9956 - val_accuracy: 0.6417 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9487 - accuracy: 0.6143 - val_loss: 1.0943 - val_accuracy: 0.6188 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 0.91721
# 28/28 - 22s - loss: 0.9664 - accuracy: 0.6166 - val_loss: 1.0767 - val_accuracy: 0.6028 - lr: 1.0000e-04 - 22s/epoch - 768ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9844 - accuracy: 0.6101 - val_loss: 1.0410 - val_accuracy: 0.6048 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9188 - accuracy: 0.6339 - val_loss: 0.9661 - val_accuracy: 0.6446 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.8963 - accuracy: 0.6294 - val_loss: 1.1209 - val_accuracy: 0.6006 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.9570 - accuracy: 0.6078 - val_loss: 1.0201 - val_accuracy: 0.6271 - lr: 1.0000e-04 - 21s/epoch - 765ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.8864 - accuracy: 0.6370 - val_loss: 0.9267 - val_accuracy: 0.6633 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.8345 - accuracy: 0.6673 - val_loss: 0.9407 - val_accuracy: 0.6471 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 0.91721
# 28/28 - 21s - loss: 0.8125 - accuracy: 0.6847 - val_loss: 1.0039 - val_accuracy: 0.6040 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss improved from 0.91721 to 0.87379, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 0.8184 - accuracy: 0.6754 - val_loss: 0.8738 - val_accuracy: 0.6614 - lr: 1.0000e-04 - 22s/epoch - 790ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 0.87379
# 28/28 - 21s - loss: 0.8130 - accuracy: 0.6747 - val_loss: 0.9191 - val_accuracy: 0.6553 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 0.87379
# 28/28 - 21s - loss: 0.8261 - accuracy: 0.6837 - val_loss: 0.8923 - val_accuracy: 0.6615 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss improved from 0.87379 to 0.82011, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 0.7983 - accuracy: 0.6905 - val_loss: 0.8201 - val_accuracy: 0.6874 - lr: 1.0000e-04 - 22s/epoch - 791ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss improved from 0.82011 to 0.80356, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_bl_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 22s - loss: 0.7778 - accuracy: 0.6983 - val_loss: 0.8036 - val_accuracy: 0.6992 - lr: 1.0000e-04 - 22s/epoch - 791ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7292 - accuracy: 0.7231 - val_loss: 0.8286 - val_accuracy: 0.6941 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7370 - accuracy: 0.7169 - val_loss: 0.8667 - val_accuracy: 0.6628 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7261 - accuracy: 0.7273 - val_loss: 0.8962 - val_accuracy: 0.6917 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.8805 - accuracy: 0.6773 - val_loss: 0.8861 - val_accuracy: 0.6449 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.8613 - accuracy: 0.6620 - val_loss: 0.9580 - val_accuracy: 0.6348 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.8350 - accuracy: 0.6779 - val_loss: 0.8732 - val_accuracy: 0.6730 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7432 - accuracy: 0.7186 - val_loss: 0.8742 - val_accuracy: 0.6753 - lr: 1.0000e-04 - 21s/epoch - 765ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7671 - accuracy: 0.7083 - val_loss: 0.8185 - val_accuracy: 0.6794 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.6989 - accuracy: 0.7389 - val_loss: 0.8480 - val_accuracy: 0.6725 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7272 - accuracy: 0.7181 - val_loss: 0.8600 - val_accuracy: 0.6555 - lr: 1.0000e-04 - 21s/epoch - 767ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7297 - accuracy: 0.7257 - val_loss: 0.8132 - val_accuracy: 0.6714 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7055 - accuracy: 0.7352 - val_loss: 0.8375 - val_accuracy: 0.6831 - lr: 1.0000e-04 - 21s/epoch - 765ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.6799 - accuracy: 0.7552 - val_loss: 0.9669 - val_accuracy: 0.6096 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7077 - accuracy: 0.7380 - val_loss: 0.9756 - val_accuracy: 0.6550 - lr: 1.0000e-04 - 21s/epoch - 765ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 0.80356
# 28/28 - 21s - loss: 0.7244 - accuracy: 0.7251 - val_loss: 0.8130 - val_accuracy: 0.6984 - lr: 1.0000e-04 - 21s/epoch - 766ms/step
# Epoch 84: early stopping
# Done

# %%
score = TUNet_Score(
    exp1_model, 
    os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'),
    exp1_rgb_X_test,
    exp1_ir_X_test,
    exp1_y_test)
# Out:
# Test loss: 0.7048945426940918
# Test accuracy: 0.7339894771575928

# %%
y_pred = TUNet_Predict(exp1_model, exp1_rgb_X_test, exp1_ir_X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
TUNet_Display(exp1_rgb_X_test, exp1_ir_X_test, exp1_y_test, y_pred)

# %%
TUNet_Metrics(exp1_y_test, y_pred, os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'))
# Out:
# Mean IoU: 0.4462142471764574
# Pixel accuracy: 0.7339894589676058
# Mean accuracy: 0.585391743160842
# Frequency-Weighted IoU: 0.7177199601144143
