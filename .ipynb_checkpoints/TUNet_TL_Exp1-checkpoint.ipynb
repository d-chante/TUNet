# %% [markdown]
# # TUNet ML

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train && ls

exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val.npy')
exp1_y_val =load(VAL_DIR + '/exp1_y_val.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test.npy')
exp1_y_test =load(TEST_DIR + '/exp1_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FIRM-WEIGHT INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-07-15 19:13:13.019567: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sat Jul 15 19:13:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   25C    P8     9W / 250W |      4MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   31C    P5    17W / 125W |   1134MiB /  6144MiB |     44%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment1/Train
# exp1_ir_X_train.npy  exp1_rgb_X_train.npy  exp1_y_train.npy
# Done

# %%
'''
MODEL PARAMS
'''
BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

EXP1_FILENAME = "augmented_tunet_ml_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### TUNet ML Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def TUNet_ML():
    '''
    INPUT
    '''
    # Expected inputs are an RGB and an IR image
    input_rgb = Input((572, 572, 3))
    input_ir = Input((572, 572))
    input_ir = tf.expand_dims(input_ir, axis=-1)
    
    '''
    CONTRACTION PATH
    '''
    c1_rgb, c2_rgb, c3_rgb, c4_rgb, p4_rgb = ContractionPath(input_rgb)
    c1_ir, c2_ir, c3_ir, c4_ir, p4_ir = ContractionPath(input_ir)
    
    c1_cat = tf.concat([c1_rgb, c1_ir], axis=-1)
    c2_cat = tf.concat([c2_rgb, c2_ir], axis=-1)
    c3_cat = tf.concat([c3_rgb, c3_ir], axis=-1)
    c4_cat = tf.concat([c4_rgb, c4_ir], axis=-1)
    p4_cat = tf.concat([p4_rgb, p4_ir], axis=-1)
    
    '''
    EXPANSION PATH
    '''
    cout = ExpansionPath(c1_cat, c2_cat, c3_cat, c4_cat, p4_cat)

    '''
    OUTPUT
    '''
    softmax_output = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout)
    softmax_output = resize(softmax_output, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs=[input_rgb, input_ir], outputs=softmax_output)

'''
TRAIN
'''
def TUNet_Train(model, weights_filename, 
               X_rgb_train, X_ir_train, y_train, 
               X_rgb_val, X_ir_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
    
            history = model.fit(
                [X_rgb_train, X_ir_train], y_train,
                validation_data=([X_rgb_val, X_ir_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def TUNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, X_ir_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test, X_ir_test], y_test, verbose=0)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def TUNet_Predict(model, X_rgb_test, X_ir_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test, X_ir_test])
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def TUNet_Display(X_rgb_test, X_ir_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 4, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(X_ir_test[n], cmap='gray')
    axes[2].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[3].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("IR")
    axes[2].set_title("Annotation")
    axes[3].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
        
'''
CALCULATE METRICS
'''
def TUNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)
    
    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    
print("Done")
# Out:
# Done

# %%
exp1_model = TUNet_ML()
# Out:
# (None, 560, 560, 64)
# (None, 572, 572, 7)

# %%
TUNet_Train(exp1_model, os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'), 
                exp1_rgb_X_train, exp1_ir_X_train, exp1_y_train,
                exp1_rgb_X_val, exp1_ir_X_val, exp1_y_val)

print("Done")
# Out:
# Epoch 1/1000
# 2023-07-15 19:26:10.276756: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_3/dropout_36/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-07-15 19:26:11.100583: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# Epoch 1: val_loss improved from inf to 1.70417, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 44s - loss: 1.7531 - accuracy: 0.3111 - val_loss: 1.7042 - val_accuracy: 0.2842 - lr: 1.0000e-04 - 44s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 1.70417 to 1.68509, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.5736 - accuracy: 0.3733 - val_loss: 1.6851 - val_accuracy: 0.2807 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 1.68509 to 1.65269, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.5523 - accuracy: 0.3837 - val_loss: 1.6527 - val_accuracy: 0.2808 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 1.65269
# 28/28 - 29s - loss: 1.5534 - accuracy: 0.3547 - val_loss: 1.6969 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 1.65269 to 1.65181, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.5564 - accuracy: 0.3792 - val_loss: 1.6518 - val_accuracy: 0.2807 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 1.65181 to 1.64220, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.5398 - accuracy: 0.3846 - val_loss: 1.6422 - val_accuracy: 0.2808 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 1.64220 to 1.62532, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.5409 - accuracy: 0.3473 - val_loss: 1.6253 - val_accuracy: 0.2808 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 1.62532
# 28/28 - 29s - loss: 1.5226 - accuracy: 0.3856 - val_loss: 1.6352 - val_accuracy: 0.2810 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 1.62532
# 28/28 - 30s - loss: 1.5169 - accuracy: 0.3804 - val_loss: 1.6495 - val_accuracy: 0.2809 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 1.62532 to 1.58620, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.4733 - accuracy: 0.3898 - val_loss: 1.5862 - val_accuracy: 0.3102 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 1.58620 to 1.52843, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.4719 - accuracy: 0.3818 - val_loss: 1.5284 - val_accuracy: 0.3135 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss improved from 1.52843 to 1.47083, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.4105 - accuracy: 0.4021 - val_loss: 1.4708 - val_accuracy: 0.3246 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 1.47083 to 1.38479, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.3854 - accuracy: 0.3561 - val_loss: 1.3848 - val_accuracy: 0.4541 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 1.38479
# 28/28 - 29s - loss: 1.3894 - accuracy: 0.3878 - val_loss: 1.5901 - val_accuracy: 0.3007 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 1.38479
# 28/28 - 29s - loss: 1.3740 - accuracy: 0.4178 - val_loss: 1.4275 - val_accuracy: 0.3543 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss improved from 1.38479 to 1.34288, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.3319 - accuracy: 0.4335 - val_loss: 1.3429 - val_accuracy: 0.3716 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 1.34288
# 28/28 - 29s - loss: 1.3241 - accuracy: 0.4010 - val_loss: 1.4592 - val_accuracy: 0.4061 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 18/1000
#
# Epoch 18: val_loss improved from 1.34288 to 1.26236, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.2856 - accuracy: 0.4246 - val_loss: 1.2624 - val_accuracy: 0.4705 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 1.26236
# 28/28 - 29s - loss: 1.2346 - accuracy: 0.4126 - val_loss: 1.3431 - val_accuracy: 0.3724 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 20/1000
#
# Epoch 20: val_loss improved from 1.26236 to 1.22042, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.1779 - accuracy: 0.4802 - val_loss: 1.2204 - val_accuracy: 0.5312 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 1.22042
# 28/28 - 29s - loss: 1.1778 - accuracy: 0.4957 - val_loss: 1.2362 - val_accuracy: 0.5759 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 1.22042
# 28/28 - 29s - loss: 1.2181 - accuracy: 0.4971 - val_loss: 1.2226 - val_accuracy: 0.5006 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 1.22042 to 1.19825, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.2505 - accuracy: 0.4696 - val_loss: 1.1983 - val_accuracy: 0.5672 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 1.19825 to 1.11396, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.1459 - accuracy: 0.5246 - val_loss: 1.1140 - val_accuracy: 0.5923 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 1.11396
# 28/28 - 29s - loss: 1.1180 - accuracy: 0.5442 - val_loss: 1.1753 - val_accuracy: 0.5209 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 1.11396
# 28/28 - 29s - loss: 1.1525 - accuracy: 0.5308 - val_loss: 1.1767 - val_accuracy: 0.5710 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 27/1000
#
# Epoch 27: val_loss improved from 1.11396 to 1.08745, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.1037 - accuracy: 0.5408 - val_loss: 1.0875 - val_accuracy: 0.5882 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 1.08745 to 1.08201, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.0903 - accuracy: 0.5411 - val_loss: 1.0820 - val_accuracy: 0.5892 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 1.08201
# 28/28 - 29s - loss: 1.0803 - accuracy: 0.5312 - val_loss: 1.1342 - val_accuracy: 0.5539 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 30/1000
#
# Epoch 30: val_loss improved from 1.08201 to 1.01284, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.0278 - accuracy: 0.5790 - val_loss: 1.0128 - val_accuracy: 0.6036 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 1.01284
# 28/28 - 29s - loss: 1.1328 - accuracy: 0.5598 - val_loss: 1.3357 - val_accuracy: 0.4929 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 1.01284
# 28/28 - 29s - loss: 1.1030 - accuracy: 0.5394 - val_loss: 1.0247 - val_accuracy: 0.6214 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 1.01284
# 28/28 - 29s - loss: 1.0948 - accuracy: 0.5505 - val_loss: 1.1100 - val_accuracy: 0.5559 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 1.01284 to 0.98967, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.0287 - accuracy: 0.5726 - val_loss: 0.9897 - val_accuracy: 0.6151 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 35/1000
#
# Epoch 35: val_loss improved from 0.98967 to 0.98466, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 1.0132 - accuracy: 0.5792 - val_loss: 0.9847 - val_accuracy: 0.6147 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 0.98466
# 28/28 - 29s - loss: 1.0573 - accuracy: 0.5544 - val_loss: 1.0630 - val_accuracy: 0.5944 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 0.98466
# 28/28 - 29s - loss: 1.0662 - accuracy: 0.5474 - val_loss: 1.0167 - val_accuracy: 0.5997 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 38/1000
#
# Epoch 38: val_loss improved from 0.98466 to 0.95832, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.9939 - accuracy: 0.5762 - val_loss: 0.9583 - val_accuracy: 0.6204 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 39/1000
#
# Epoch 39: val_loss improved from 0.95832 to 0.91269, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.9674 - accuracy: 0.5886 - val_loss: 0.9127 - val_accuracy: 0.6504 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9313 - accuracy: 0.6098 - val_loss: 0.9274 - val_accuracy: 0.6421 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9389 - accuracy: 0.6045 - val_loss: 0.9652 - val_accuracy: 0.5902 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9004 - accuracy: 0.6416 - val_loss: 1.0754 - val_accuracy: 0.5809 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9509 - accuracy: 0.6001 - val_loss: 0.9242 - val_accuracy: 0.6443 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.8721 - accuracy: 0.6518 - val_loss: 0.9600 - val_accuracy: 0.5847 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9133 - accuracy: 0.6177 - val_loss: 1.1264 - val_accuracy: 0.5738 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.8962 - accuracy: 0.6321 - val_loss: 0.9614 - val_accuracy: 0.6080 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 0.91269
# 28/28 - 29s - loss: 0.9005 - accuracy: 0.6383 - val_loss: 0.9638 - val_accuracy: 0.6245 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 48/1000
#
# Epoch 48: val_loss improved from 0.91269 to 0.82297, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.9304 - accuracy: 0.5986 - val_loss: 0.8230 - val_accuracy: 0.6691 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8889 - accuracy: 0.6584 - val_loss: 0.8937 - val_accuracy: 0.6469 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8460 - accuracy: 0.6591 - val_loss: 0.9285 - val_accuracy: 0.6081 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8383 - accuracy: 0.6694 - val_loss: 0.9442 - val_accuracy: 0.6307 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8419 - accuracy: 0.6645 - val_loss: 0.8953 - val_accuracy: 0.6373 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8837 - accuracy: 0.6466 - val_loss: 0.9043 - val_accuracy: 0.6164 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.8377 - accuracy: 0.6624 - val_loss: 0.8286 - val_accuracy: 0.6668 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 0.82297
# 28/28 - 29s - loss: 0.7996 - accuracy: 0.6883 - val_loss: 0.8349 - val_accuracy: 0.6573 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 56/1000
#
# Epoch 56: val_loss improved from 0.82297 to 0.79867, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.7900 - accuracy: 0.6902 - val_loss: 0.7987 - val_accuracy: 0.6833 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 0.79867
# 28/28 - 29s - loss: 0.7669 - accuracy: 0.6922 - val_loss: 0.9593 - val_accuracy: 0.6099 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 58/1000
#
# Epoch 58: val_loss improved from 0.79867 to 0.78975, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.7275 - accuracy: 0.7130 - val_loss: 0.7898 - val_accuracy: 0.6771 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7002 - accuracy: 0.7327 - val_loss: 0.8565 - val_accuracy: 0.6561 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7236 - accuracy: 0.7116 - val_loss: 0.8751 - val_accuracy: 0.6197 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7951 - accuracy: 0.6836 - val_loss: 0.8012 - val_accuracy: 0.6834 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7785 - accuracy: 0.6850 - val_loss: 0.8632 - val_accuracy: 0.6482 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7199 - accuracy: 0.7236 - val_loss: 0.7963 - val_accuracy: 0.7005 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 0.78975
# 28/28 - 29s - loss: 0.7252 - accuracy: 0.7111 - val_loss: 0.8435 - val_accuracy: 0.6611 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 65/1000
#
# Epoch 65: val_loss improved from 0.78975 to 0.78144, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.7189 - accuracy: 0.7081 - val_loss: 0.7814 - val_accuracy: 0.6771 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 0.78144
# 28/28 - 29s - loss: 0.7306 - accuracy: 0.7067 - val_loss: 0.9763 - val_accuracy: 0.6119 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 67/1000
#
# Epoch 67: val_loss improved from 0.78144 to 0.74336, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.7205 - accuracy: 0.7187 - val_loss: 0.7434 - val_accuracy: 0.7038 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 0.74336
# 28/28 - 29s - loss: 0.6537 - accuracy: 0.7443 - val_loss: 0.8341 - val_accuracy: 0.6558 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 0.74336
# 28/28 - 29s - loss: 0.7276 - accuracy: 0.7181 - val_loss: 0.7858 - val_accuracy: 0.6940 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 0.74336
# 28/28 - 29s - loss: 0.6667 - accuracy: 0.7435 - val_loss: 0.7438 - val_accuracy: 0.6978 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 71/1000
#
# Epoch 71: val_loss improved from 0.74336 to 0.72573, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.6473 - accuracy: 0.7505 - val_loss: 0.7257 - val_accuracy: 0.7002 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 0.72573
# 28/28 - 29s - loss: 0.6348 - accuracy: 0.7639 - val_loss: 0.8011 - val_accuracy: 0.6728 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 0.72573
# 28/28 - 29s - loss: 0.7547 - accuracy: 0.6990 - val_loss: 0.8865 - val_accuracy: 0.6521 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 74/1000
#
# Epoch 74: val_loss improved from 0.72573 to 0.71568, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.6508 - accuracy: 0.7524 - val_loss: 0.7157 - val_accuracy: 0.7059 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.6416 - accuracy: 0.7581 - val_loss: 0.8403 - val_accuracy: 0.6517 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.6745 - accuracy: 0.7467 - val_loss: 0.7743 - val_accuracy: 0.7025 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.6090 - accuracy: 0.7684 - val_loss: 0.7572 - val_accuracy: 0.6887 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.6223 - accuracy: 0.7634 - val_loss: 0.7799 - val_accuracy: 0.6841 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.5603 - accuracy: 0.7913 - val_loss: 0.8951 - val_accuracy: 0.6540 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.5754 - accuracy: 0.7795 - val_loss: 0.7431 - val_accuracy: 0.7153 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 0.71568
# 28/28 - 29s - loss: 0.5207 - accuracy: 0.8034 - val_loss: 0.7821 - val_accuracy: 0.6978 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 82/1000
#
# Epoch 82: val_loss improved from 0.71568 to 0.69299, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.5531 - accuracy: 0.7882 - val_loss: 0.6930 - val_accuracy: 0.7310 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.5301 - accuracy: 0.8033 - val_loss: 0.7699 - val_accuracy: 0.6976 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.5879 - accuracy: 0.7743 - val_loss: 0.7844 - val_accuracy: 0.6904 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.6314 - accuracy: 0.7585 - val_loss: 0.9218 - val_accuracy: 0.6307 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.5346 - accuracy: 0.8003 - val_loss: 0.7093 - val_accuracy: 0.7260 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.4797 - accuracy: 0.8241 - val_loss: 0.8436 - val_accuracy: 0.6903 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.4790 - accuracy: 0.8216 - val_loss: 0.7375 - val_accuracy: 0.7262 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.5334 - accuracy: 0.8029 - val_loss: 0.7603 - val_accuracy: 0.7098 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.4980 - accuracy: 0.8131 - val_loss: 0.6955 - val_accuracy: 0.7333 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.4618 - accuracy: 0.8274 - val_loss: 0.7354 - val_accuracy: 0.7303 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 0.69299
# 28/28 - 29s - loss: 0.5183 - accuracy: 0.8044 - val_loss: 0.7580 - val_accuracy: 0.7007 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 93/1000
#
# Epoch 93: val_loss improved from 0.69299 to 0.67645, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_ml_exp1_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 28/28 - 30s - loss: 0.5013 - accuracy: 0.8142 - val_loss: 0.6765 - val_accuracy: 0.7360 - lr: 1.0000e-04 - 30s/epoch - 1s/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.4017 - accuracy: 0.8552 - val_loss: 0.7599 - val_accuracy: 0.7310 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.5070 - accuracy: 0.8110 - val_loss: 0.7919 - val_accuracy: 0.6940 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.5643 - accuracy: 0.7810 - val_loss: 0.7855 - val_accuracy: 0.7123 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.4502 - accuracy: 0.8342 - val_loss: 0.7785 - val_accuracy: 0.7209 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.4144 - accuracy: 0.8482 - val_loss: 0.7781 - val_accuracy: 0.7318 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3497 - accuracy: 0.8750 - val_loss: 0.7679 - val_accuracy: 0.7375 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3533 - accuracy: 0.8743 - val_loss: 0.8114 - val_accuracy: 0.7335 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3511 - accuracy: 0.8734 - val_loss: 0.7454 - val_accuracy: 0.7483 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3187 - accuracy: 0.8894 - val_loss: 0.8335 - val_accuracy: 0.7351 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3424 - accuracy: 0.8816 - val_loss: 0.8076 - val_accuracy: 0.7356 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.4377 - accuracy: 0.8448 - val_loss: 0.8160 - val_accuracy: 0.7048 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.4291 - accuracy: 0.8500 - val_loss: 0.9223 - val_accuracy: 0.6734 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3686 - accuracy: 0.8680 - val_loss: 0.8060 - val_accuracy: 0.7367 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.3026 - accuracy: 0.8967 - val_loss: 0.7996 - val_accuracy: 0.7425 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 0.67645
# 28/28 - 29s - loss: 0.2808 - accuracy: 0.9035 - val_loss: 0.7886 - val_accuracy: 0.7484 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 108: early stopping
# Done

# %%
score = TUNet_Score(
    exp1_model, 
    os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'),
    exp1_rgb_X_test,
    exp1_ir_X_test,
    exp1_y_test)
# Out:
# Test loss: 0.6095669865608215
# Test accuracy: 0.7692767381668091

# %%
y_pred = TUNet_Predict(exp1_model, exp1_rgb_X_test, exp1_ir_X_test)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
TUNet_Display(exp1_rgb_X_test, exp1_ir_X_test, exp1_y_test, y_pred)

# %%
TUNet_Metrics(exp1_y_test, y_pred, os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'))
# Out:
# Mean IoU: 0.5567615154022271
# Pixel accuracy: 0.7692767241499759
# Mean accuracy: 0.7018701602619271
# Frequency-Weighted IoU: 0.7596177266430596
