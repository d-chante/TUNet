# %% [markdown]
# # TUNet TL Exp 2

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed_wAugmentation/Experiment2/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment2/Train && ls

exp2_rgb_X_train = load(TRAIN_DIR + '/exp2_rgb_X_train.npy')
exp2_ir_X_train = load(TRAIN_DIR + '/exp2_ir_X_train.npy')
exp2_y_train = load(TRAIN_DIR + '/exp2_y_train.npy')

'''
VALIDATION DATA
'''
exp2_rgb_X_val = load(VAL_DIR + '/exp2_rgb_X_val.npy')
exp2_ir_X_val = load(VAL_DIR + '/exp2_ir_X_val.npy')
exp2_y_val =load(VAL_DIR + '/exp2_y_val.npy')

'''
TEST DATA
'''
exp2_rgb_X_test = load(TEST_DIR + '/exp2_rgb_X_test.npy')
exp2_ir_X_test = load(TEST_DIR + '/exp2_ir_X_test.npy')
exp2_y_test =load(TEST_DIR + '/exp2_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FREQUENCY-WEIGHTED INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', 7)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()

print("Done")
# Out:
# 2023-08-21 15:42:24.727949: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Mon Aug 21 15:42:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   33C    P8     9W / 250W |      4MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   35C    P5    15W / 125W |    387MiB /  6144MiB |     31%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed_wAugmentation/Experiment2/Train
# exp2_ir_X_train.npy  exp2_rgb_X_train.npy  exp2_y_train.npy
# Done

# %%
'''
SPLITTIG DATA SETS INTO BLOCKS
'''

SPLIT = 2

'''
TRAINING DATA SPLIT
'''
exp2_rgb_X_train_split = np.array_split(exp2_rgb_X_train, SPLIT)
exp2_ir_X_train_split = np.array_split(exp2_ir_X_train, SPLIT)
exp2_y_train_split = np.array_split(exp2_y_train, SPLIT)

'''
VALIDATION DATA
'''
exp2_rgb_X_val_split = np.array_split(exp2_rgb_X_val, SPLIT)
exp2_ir_X_val_split = np.array_split(exp2_ir_X_val, SPLIT)
exp2_y_val_split = np.array_split(exp2_y_val, SPLIT)

print("Done")
# Out:
# Done

# %%
'''
MODEL PARAMS
'''
BATCH_SIZE = 2
EPOCHS = 1000 

LEARNING_RATE = 1e-4
PATIENCE = 15
FACTOR = 0.1

EXP2_FILENAME = "augmented_tunet_tl_split_exp2_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### TUNet TL Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def TUNet_TL():
    '''
    INPUT
    '''
    # Expected inputs are an RGB and an IR image
    input_rgb = Input((572, 572, 3))
    input_ir = Input((572, 572))
    input_ir = tf.expand_dims(input_ir, axis=-1)
    
    '''
    CONTRACTION PATH
    '''
    c1_rgb, c2_rgb, c3_rgb, c4_rgb, p4_rgb = ContractionPath(input_rgb)
    c1_ir, c2_ir, c3_ir, c4_ir, p4_ir = ContractionPath(input_ir)
    
    '''
    EXPANSION PATH
    '''
    cout_rgb = ExpansionPath(c1_rgb, c2_rgb, c3_rgb, c4_rgb, p4_rgb)
    cout_ir = ExpansionPath(c1_ir, c2_ir, c3_ir, c4_ir, p4_ir)
    
    cout_cat = concatenate([cout_rgb, cout_ir], axis=-1)

    '''
    OUTPUT
    '''
    softmax_output = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout_cat)
    softmax_output = resize(softmax_output, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs=[input_rgb, input_ir], outputs=softmax_output)

'''
TRAIN
'''
def TUNet_Train(model, weights_filename, 
               X_rgb_train, X_ir_train, y_train, 
               X_rgb_val, X_ir_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
                
            for i in range(SPLIT):
                
                print("\n====== Batch " + repr(i+1) + " ======\n")
                
                history = model.fit(
                    [X_rgb_train[i], X_ir_train[i]], y_train[i],
                    validation_data=([X_rgb_val[i], X_ir_val[i]], y_val[i]),
                    batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def TUNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, X_ir_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test, X_ir_test], y_test, batch_size=2, verbose=1)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def TUNet_Predict(model, X_rgb_test, X_ir_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test, X_ir_test], batch_size=2)
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def TUNet_Display(X_rgb_test, X_ir_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 4, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(X_ir_test[n], cmap='gray')
    axes[2].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[3].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("IR")
    axes[2].set_title("Annotation")
    axes[3].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
        
'''
CALCULATE METRICS
'''
def TUNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)
    
    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")
    
print("Done")
# Out:
# Done

# %%
try:
    with tf.device(gpu_p40):
        exp2_model = TUNet_TL()
except RuntimeError as e:
    print(e)
    
print("Done")
# Out:
# Done

# %%
TUNet_Train(exp2_model, os.path.join(WEIGHTS_PATH, EXP2_FILENAME + '.h5'), 
                exp2_rgb_X_train_split, exp2_ir_X_train_split, exp2_y_train_split,
                exp2_rgb_X_val_split, exp2_ir_X_val_split, exp2_y_val_split)

print("Done")
# Out:
# ====== Batch 1 ======
#
# Epoch 1/1000
# 2023-08-21 15:42:52.276619: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_16/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-08-21 15:42:53.088725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# Epoch 1: val_loss improved from inf to 1.63504, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 46s - loss: 1.7967 - accuracy: 0.3124 - val_loss: 1.6350 - val_accuracy: 0.4781 - lr: 1.0000e-04 - 46s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 1.63504 to 1.57373, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.6239 - accuracy: 0.3296 - val_loss: 1.5737 - val_accuracy: 0.3873 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 1.57373 to 1.51321, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.5963 - accuracy: 0.3747 - val_loss: 1.5132 - val_accuracy: 0.4345 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 1.51321 to 1.48382, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.5660 - accuracy: 0.3396 - val_loss: 1.4838 - val_accuracy: 0.3876 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 1.48382
# 25/25 - 25s - loss: 1.5410 - accuracy: 0.3403 - val_loss: 1.4953 - val_accuracy: 0.3873 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 1.48382
# 25/25 - 25s - loss: 1.5351 - accuracy: 0.3807 - val_loss: 1.5031 - val_accuracy: 0.3874 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 1.48382
# 25/25 - 25s - loss: 1.5250 - accuracy: 0.3875 - val_loss: 1.4894 - val_accuracy: 0.3843 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 1.48382 to 1.43988, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.4822 - accuracy: 0.4092 - val_loss: 1.4399 - val_accuracy: 0.3817 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 1.43988
# 25/25 - 25s - loss: 1.5036 - accuracy: 0.4298 - val_loss: 1.4843 - val_accuracy: 0.3958 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 1.43988
# 25/25 - 25s - loss: 1.4724 - accuracy: 0.4370 - val_loss: 1.4669 - val_accuracy: 0.3804 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 1.43988
# 25/25 - 25s - loss: 1.4706 - accuracy: 0.4280 - val_loss: 1.4572 - val_accuracy: 0.3811 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 1.43988
# 25/25 - 25s - loss: 1.4572 - accuracy: 0.4273 - val_loss: 1.4969 - val_accuracy: 0.3826 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 1.43988
# 25/25 - 25s - loss: 1.4347 - accuracy: 0.4450 - val_loss: 1.4501 - val_accuracy: 0.3845 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 14/1000
#
# Epoch 14: val_loss improved from 1.43988 to 1.42760, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.4215 - accuracy: 0.4431 - val_loss: 1.4276 - val_accuracy: 0.3961 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 1.42760
# 25/25 - 25s - loss: 1.4819 - accuracy: 0.3857 - val_loss: 1.4486 - val_accuracy: 0.3846 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 1.42760
# 25/25 - 25s - loss: 1.4281 - accuracy: 0.4464 - val_loss: 1.4507 - val_accuracy: 0.3947 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 1.42760 to 1.41261, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.3993 - accuracy: 0.4321 - val_loss: 1.4126 - val_accuracy: 0.3928 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 18/1000
#
# Epoch 18: val_loss improved from 1.41261 to 1.40129, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.3969 - accuracy: 0.4438 - val_loss: 1.4013 - val_accuracy: 0.3998 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 1.40129
# 25/25 - 25s - loss: 1.3944 - accuracy: 0.4499 - val_loss: 1.4191 - val_accuracy: 0.4061 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 20/1000
#
# Epoch 20: val_loss improved from 1.40129 to 1.39871, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.3630 - accuracy: 0.4350 - val_loss: 1.3987 - val_accuracy: 0.4234 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 1.39871
# 25/25 - 25s - loss: 1.4441 - accuracy: 0.4216 - val_loss: 1.4622 - val_accuracy: 0.5549 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 1.39871
# 25/25 - 25s - loss: 1.4131 - accuracy: 0.4248 - val_loss: 1.4087 - val_accuracy: 0.4534 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 1.39871 to 1.36958, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.3485 - accuracy: 0.4403 - val_loss: 1.3696 - val_accuracy: 0.4748 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 1.36958
# 25/25 - 25s - loss: 1.3389 - accuracy: 0.4667 - val_loss: 1.3969 - val_accuracy: 0.5668 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 1.36958
# 25/25 - 25s - loss: 1.3334 - accuracy: 0.4654 - val_loss: 1.3839 - val_accuracy: 0.5649 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 1.36958
# 25/25 - 25s - loss: 1.3315 - accuracy: 0.4478 - val_loss: 1.4047 - val_accuracy: 0.4683 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 1.36958
# 25/25 - 25s - loss: 1.3618 - accuracy: 0.4454 - val_loss: 1.3785 - val_accuracy: 0.4580 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 1.36958
# 25/25 - 25s - loss: 1.2828 - accuracy: 0.4800 - val_loss: 1.3929 - val_accuracy: 0.4897 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 29/1000
#
# Epoch 29: val_loss improved from 1.36958 to 1.32824, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.2840 - accuracy: 0.5132 - val_loss: 1.3282 - val_accuracy: 0.5325 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 1.32824
# 25/25 - 25s - loss: 1.3107 - accuracy: 0.5058 - val_loss: 1.3300 - val_accuracy: 0.5549 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 1.32824
# 25/25 - 25s - loss: 1.2632 - accuracy: 0.5233 - val_loss: 1.3719 - val_accuracy: 0.5120 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 1.32824
# 25/25 - 25s - loss: 1.3023 - accuracy: 0.5077 - val_loss: 1.3652 - val_accuracy: 0.5193 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 33/1000
#
# Epoch 33: val_loss improved from 1.32824 to 1.31137, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.2541 - accuracy: 0.5049 - val_loss: 1.3114 - val_accuracy: 0.5640 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 1.31137 to 1.30156, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.2376 - accuracy: 0.5353 - val_loss: 1.3016 - val_accuracy: 0.5651 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.2852 - accuracy: 0.5130 - val_loss: 1.3764 - val_accuracy: 0.5004 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.2738 - accuracy: 0.4936 - val_loss: 1.4053 - val_accuracy: 0.4683 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.2314 - accuracy: 0.5392 - val_loss: 1.3042 - val_accuracy: 0.5379 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.2119 - accuracy: 0.5441 - val_loss: 1.3169 - val_accuracy: 0.5339 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.2162 - accuracy: 0.5143 - val_loss: 1.3116 - val_accuracy: 0.5461 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.1862 - accuracy: 0.5202 - val_loss: 1.3592 - val_accuracy: 0.4935 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 1.30156
# 25/25 - 25s - loss: 1.1838 - accuracy: 0.5421 - val_loss: 1.3238 - val_accuracy: 0.5174 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 42/1000
#
# Epoch 42: val_loss improved from 1.30156 to 1.29978, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.1661 - accuracy: 0.5523 - val_loss: 1.2998 - val_accuracy: 0.5225 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 43/1000
#
# Epoch 43: val_loss improved from 1.29978 to 1.27624, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.1547 - accuracy: 0.5459 - val_loss: 1.2762 - val_accuracy: 0.5639 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1604 - accuracy: 0.5495 - val_loss: 1.3228 - val_accuracy: 0.5411 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1975 - accuracy: 0.5479 - val_loss: 1.2995 - val_accuracy: 0.5610 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1616 - accuracy: 0.5656 - val_loss: 1.3060 - val_accuracy: 0.5494 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1122 - accuracy: 0.5858 - val_loss: 1.3068 - val_accuracy: 0.5452 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1141 - accuracy: 0.5991 - val_loss: 1.4505 - val_accuracy: 0.4838 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.1249 - accuracy: 0.5979 - val_loss: 1.3387 - val_accuracy: 0.5317 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 1.27624
# 25/25 - 25s - loss: 1.0937 - accuracy: 0.5912 - val_loss: 1.2857 - val_accuracy: 0.5560 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 51/1000
#
# Epoch 51: val_loss improved from 1.27624 to 1.24762, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.0737 - accuracy: 0.6116 - val_loss: 1.2476 - val_accuracy: 0.5533 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 1.24762
# 25/25 - 25s - loss: 1.0422 - accuracy: 0.6225 - val_loss: 1.3349 - val_accuracy: 0.5129 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 1.24762
# 25/25 - 25s - loss: 1.1108 - accuracy: 0.5923 - val_loss: 1.2963 - val_accuracy: 0.5360 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 1.24762
# 25/25 - 25s - loss: 1.0346 - accuracy: 0.6307 - val_loss: 1.2480 - val_accuracy: 0.5596 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 1.24762
# 25/25 - 25s - loss: 1.0207 - accuracy: 0.6369 - val_loss: 1.2695 - val_accuracy: 0.5506 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 1.24762
# 25/25 - 25s - loss: 0.9879 - accuracy: 0.6491 - val_loss: 1.3186 - val_accuracy: 0.5594 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 57/1000
#
# Epoch 57: val_loss improved from 1.24762 to 1.24429, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.0314 - accuracy: 0.6322 - val_loss: 1.2443 - val_accuracy: 0.5408 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 58/1000
#
# Epoch 58: val_loss improved from 1.24429 to 1.20036, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.0419 - accuracy: 0.6201 - val_loss: 1.2004 - val_accuracy: 0.5621 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 1.0155 - accuracy: 0.6241 - val_loss: 1.2753 - val_accuracy: 0.5439 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9898 - accuracy: 0.6368 - val_loss: 1.2770 - val_accuracy: 0.5252 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 1.0261 - accuracy: 0.6270 - val_loss: 1.2140 - val_accuracy: 0.5563 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 1.0569 - accuracy: 0.6085 - val_loss: 1.2345 - val_accuracy: 0.5664 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 1.0356 - accuracy: 0.6360 - val_loss: 1.3174 - val_accuracy: 0.5427 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 1.0649 - accuracy: 0.6041 - val_loss: 1.2608 - val_accuracy: 0.5492 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9955 - accuracy: 0.6507 - val_loss: 1.2288 - val_accuracy: 0.5499 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9208 - accuracy: 0.6641 - val_loss: 1.2750 - val_accuracy: 0.5258 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9252 - accuracy: 0.6572 - val_loss: 1.2347 - val_accuracy: 0.5369 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9130 - accuracy: 0.6662 - val_loss: 1.3733 - val_accuracy: 0.4806 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9456 - accuracy: 0.6750 - val_loss: 1.2364 - val_accuracy: 0.5336 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9343 - accuracy: 0.6606 - val_loss: 1.3127 - val_accuracy: 0.5009 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 1.20036
# 25/25 - 25s - loss: 0.9248 - accuracy: 0.6582 - val_loss: 1.3829 - val_accuracy: 0.4751 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 72/1000
#
# Epoch 72: val_loss improved from 1.20036 to 1.16946, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.0237 - accuracy: 0.6139 - val_loss: 1.1695 - val_accuracy: 0.5795 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 1.16946
# 25/25 - 25s - loss: 0.9513 - accuracy: 0.6575 - val_loss: 1.4303 - val_accuracy: 0.5263 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 1.16946
# 25/25 - 25s - loss: 1.1351 - accuracy: 0.5722 - val_loss: 1.3059 - val_accuracy: 0.5048 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 1.16946
# 25/25 - 25s - loss: 0.9699 - accuracy: 0.6346 - val_loss: 1.2651 - val_accuracy: 0.5367 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 76/1000
#
# Epoch 76: val_loss improved from 1.16946 to 1.15282, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.9311 - accuracy: 0.6736 - val_loss: 1.1528 - val_accuracy: 0.5609 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8629 - accuracy: 0.6775 - val_loss: 1.2063 - val_accuracy: 0.5499 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8776 - accuracy: 0.6845 - val_loss: 1.1963 - val_accuracy: 0.5619 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8501 - accuracy: 0.6950 - val_loss: 1.3224 - val_accuracy: 0.5304 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.9665 - accuracy: 0.6549 - val_loss: 1.2993 - val_accuracy: 0.5603 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.9501 - accuracy: 0.6665 - val_loss: 1.2252 - val_accuracy: 0.5626 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8994 - accuracy: 0.6727 - val_loss: 1.1718 - val_accuracy: 0.5656 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8626 - accuracy: 0.6754 - val_loss: 1.2655 - val_accuracy: 0.5503 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8611 - accuracy: 0.6771 - val_loss: 1.2832 - val_accuracy: 0.5291 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.9638 - accuracy: 0.6217 - val_loss: 1.1956 - val_accuracy: 0.5549 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.9448 - accuracy: 0.6423 - val_loss: 1.2496 - val_accuracy: 0.5558 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8321 - accuracy: 0.7042 - val_loss: 1.2149 - val_accuracy: 0.5453 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8378 - accuracy: 0.6863 - val_loss: 1.1894 - val_accuracy: 0.5810 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8275 - accuracy: 0.6971 - val_loss: 1.1957 - val_accuracy: 0.5580 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8282 - accuracy: 0.6902 - val_loss: 1.2370 - val_accuracy: 0.5750 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.8494 - accuracy: 0.6845 - val_loss: 1.1709 - val_accuracy: 0.5514 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 91: early stopping
#
# ====== Batch 2 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.2539 - accuracy: 0.5305 - val_loss: 1.4459 - val_accuracy: 0.4527 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.1662 - accuracy: 0.5644 - val_loss: 1.2920 - val_accuracy: 0.5603 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.1137 - accuracy: 0.5811 - val_loss: 1.1887 - val_accuracy: 0.5467 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.0473 - accuracy: 0.6229 - val_loss: 1.1547 - val_accuracy: 0.5778 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.0315 - accuracy: 0.5959 - val_loss: 1.2099 - val_accuracy: 0.5625 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 1.0186 - accuracy: 0.6232 - val_loss: 1.2313 - val_accuracy: 0.5254 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 1.15282
# 25/25 - 25s - loss: 0.9812 - accuracy: 0.6298 - val_loss: 1.1953 - val_accuracy: 0.5676 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 1.15282 to 1.07775, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.9760 - accuracy: 0.6381 - val_loss: 1.0777 - val_accuracy: 0.6109 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 1.07775 to 1.06264, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.9245 - accuracy: 0.6480 - val_loss: 1.0626 - val_accuracy: 0.6220 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.9651 - accuracy: 0.6427 - val_loss: 1.2399 - val_accuracy: 0.5413 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8975 - accuracy: 0.6604 - val_loss: 1.5448 - val_accuracy: 0.4667 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.9638 - accuracy: 0.6380 - val_loss: 1.0947 - val_accuracy: 0.6114 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8674 - accuracy: 0.6769 - val_loss: 1.1298 - val_accuracy: 0.6120 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8989 - accuracy: 0.6778 - val_loss: 1.0857 - val_accuracy: 0.6104 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8492 - accuracy: 0.6914 - val_loss: 1.1071 - val_accuracy: 0.6093 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.9210 - accuracy: 0.6509 - val_loss: 1.1189 - val_accuracy: 0.6171 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8680 - accuracy: 0.6628 - val_loss: 1.1107 - val_accuracy: 0.6005 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.9048 - accuracy: 0.6580 - val_loss: 1.0914 - val_accuracy: 0.6086 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8451 - accuracy: 0.6857 - val_loss: 1.1572 - val_accuracy: 0.5937 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8660 - accuracy: 0.6747 - val_loss: 1.1712 - val_accuracy: 0.6039 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8192 - accuracy: 0.6912 - val_loss: 1.1087 - val_accuracy: 0.6142 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.7850 - accuracy: 0.7075 - val_loss: 1.0743 - val_accuracy: 0.6268 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.7987 - accuracy: 0.6923 - val_loss: 1.1122 - val_accuracy: 0.6212 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 1.06264
# 25/25 - 25s - loss: 0.8089 - accuracy: 0.6845 - val_loss: 1.1305 - val_accuracy: 0.6051 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 24: early stopping
#
# ====== Batch 3 ======
#
# Epoch 1/1000
# Epoch 1: val_loss improved from 1.06264 to 0.99391, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 1.0100 - accuracy: 0.6205 - val_loss: 0.9939 - val_accuracy: 0.6514 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.99391
# 25/25 - 25s - loss: 0.9024 - accuracy: 0.6420 - val_loss: 1.0190 - val_accuracy: 0.6137 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.99391
# 25/25 - 25s - loss: 0.8794 - accuracy: 0.6641 - val_loss: 1.0447 - val_accuracy: 0.6253 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.99391 to 0.94592, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.8999 - accuracy: 0.6502 - val_loss: 0.9459 - val_accuracy: 0.6548 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.94592
# 25/25 - 25s - loss: 0.8107 - accuracy: 0.6968 - val_loss: 1.0171 - val_accuracy: 0.6264 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.94592 to 0.93218, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.7542 - accuracy: 0.7195 - val_loss: 0.9322 - val_accuracy: 0.6828 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.93218
# 25/25 - 25s - loss: 0.7601 - accuracy: 0.7109 - val_loss: 1.1233 - val_accuracy: 0.6146 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 0.93218 to 0.92229, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.7992 - accuracy: 0.7087 - val_loss: 0.9223 - val_accuracy: 0.6678 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.92229
# 25/25 - 25s - loss: 0.7965 - accuracy: 0.7051 - val_loss: 0.9666 - val_accuracy: 0.6786 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.92229
# 25/25 - 25s - loss: 0.7937 - accuracy: 0.7151 - val_loss: 1.3230 - val_accuracy: 0.4962 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.92229
# 25/25 - 25s - loss: 0.9424 - accuracy: 0.5965 - val_loss: 0.9636 - val_accuracy: 0.6281 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.92229
# 25/25 - 25s - loss: 0.7485 - accuracy: 0.7303 - val_loss: 0.9849 - val_accuracy: 0.6385 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 0.92229 to 0.86441, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.6879 - accuracy: 0.7420 - val_loss: 0.8644 - val_accuracy: 0.6929 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6719 - accuracy: 0.7547 - val_loss: 0.9892 - val_accuracy: 0.6592 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7098 - accuracy: 0.7325 - val_loss: 0.9298 - val_accuracy: 0.6870 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7233 - accuracy: 0.7306 - val_loss: 0.9471 - val_accuracy: 0.6845 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6965 - accuracy: 0.7469 - val_loss: 0.8920 - val_accuracy: 0.6926 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7055 - accuracy: 0.7433 - val_loss: 0.9971 - val_accuracy: 0.6673 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6556 - accuracy: 0.7602 - val_loss: 0.9140 - val_accuracy: 0.6915 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6255 - accuracy: 0.7669 - val_loss: 0.9735 - val_accuracy: 0.6780 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6113 - accuracy: 0.7758 - val_loss: 0.9727 - val_accuracy: 0.6779 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.8107 - accuracy: 0.6938 - val_loss: 1.2369 - val_accuracy: 0.5595 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7311 - accuracy: 0.7196 - val_loss: 0.9752 - val_accuracy: 0.6754 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7804 - accuracy: 0.7086 - val_loss: 0.9421 - val_accuracy: 0.6677 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7143 - accuracy: 0.7385 - val_loss: 1.0755 - val_accuracy: 0.6049 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6386 - accuracy: 0.7537 - val_loss: 0.9946 - val_accuracy: 0.6678 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6676 - accuracy: 0.7461 - val_loss: 0.9907 - val_accuracy: 0.6813 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.5624 - accuracy: 0.7939 - val_loss: 0.9670 - val_accuracy: 0.6689 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 28: early stopping
#
# ====== Batch 4 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.8972 - accuracy: 0.6725 - val_loss: 0.9511 - val_accuracy: 0.6360 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7713 - accuracy: 0.7343 - val_loss: 1.0199 - val_accuracy: 0.6280 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.8313 - accuracy: 0.7015 - val_loss: 1.0504 - val_accuracy: 0.6130 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.8028 - accuracy: 0.7132 - val_loss: 0.9871 - val_accuracy: 0.6243 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7009 - accuracy: 0.7485 - val_loss: 1.0355 - val_accuracy: 0.6309 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7001 - accuracy: 0.7505 - val_loss: 1.0483 - val_accuracy: 0.6415 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6736 - accuracy: 0.7617 - val_loss: 1.0436 - val_accuracy: 0.6154 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.7353 - accuracy: 0.7387 - val_loss: 1.0499 - val_accuracy: 0.6173 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6957 - accuracy: 0.7551 - val_loss: 1.0603 - val_accuracy: 0.6216 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6930 - accuracy: 0.7432 - val_loss: 1.0159 - val_accuracy: 0.6065 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6272 - accuracy: 0.7676 - val_loss: 1.0820 - val_accuracy: 0.5977 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6772 - accuracy: 0.7470 - val_loss: 1.0869 - val_accuracy: 0.6067 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6384 - accuracy: 0.7796 - val_loss: 1.1018 - val_accuracy: 0.6412 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.6983 - accuracy: 0.7412 - val_loss: 1.0062 - val_accuracy: 0.6265 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.5884 - accuracy: 0.7879 - val_loss: 1.1479 - val_accuracy: 0.6119 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.86441
# 25/25 - 25s - loss: 0.5719 - accuracy: 0.7932 - val_loss: 1.1468 - val_accuracy: 0.6158 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 16: early stopping
#
# ====== Batch 5 ======
#
# Epoch 1/1000
# 2023-08-21 16:50:21.979531: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_1/dropout_16/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# Epoch 1: val_loss did not improve from 0.86441
# 25/25 - 29s - loss: 1.0751 - accuracy: 0.6141 - val_loss: 0.9370 - val_accuracy: 0.6348 - lr: 1.0000e-04 - 29s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 0.86441 to 0.82906, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.9343 - accuracy: 0.6564 - val_loss: 0.8291 - val_accuracy: 0.6841 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.82906
# 25/25 - 25s - loss: 0.8307 - accuracy: 0.6893 - val_loss: 0.9050 - val_accuracy: 0.6660 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.82906
# 25/25 - 25s - loss: 0.7964 - accuracy: 0.7029 - val_loss: 0.8710 - val_accuracy: 0.6881 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 0.82906 to 0.80993, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.7359 - accuracy: 0.7320 - val_loss: 0.8099 - val_accuracy: 0.6888 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 0.80993 to 0.80213, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.7550 - accuracy: 0.7138 - val_loss: 0.8021 - val_accuracy: 0.7092 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.7611 - accuracy: 0.7239 - val_loss: 0.8268 - val_accuracy: 0.6795 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.7399 - accuracy: 0.7260 - val_loss: 0.8566 - val_accuracy: 0.6588 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6840 - accuracy: 0.7462 - val_loss: 0.8949 - val_accuracy: 0.6548 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6480 - accuracy: 0.7616 - val_loss: 0.8774 - val_accuracy: 0.6876 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6510 - accuracy: 0.7586 - val_loss: 0.8943 - val_accuracy: 0.6606 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.7134 - accuracy: 0.7398 - val_loss: 0.9057 - val_accuracy: 0.6631 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6329 - accuracy: 0.7666 - val_loss: 0.8998 - val_accuracy: 0.6570 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6260 - accuracy: 0.7658 - val_loss: 0.8748 - val_accuracy: 0.6779 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5625 - accuracy: 0.7939 - val_loss: 0.9309 - val_accuracy: 0.6569 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6802 - accuracy: 0.7501 - val_loss: 1.0176 - val_accuracy: 0.6087 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.8694 - accuracy: 0.6682 - val_loss: 1.1677 - val_accuracy: 0.5640 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.7956 - accuracy: 0.6982 - val_loss: 0.9118 - val_accuracy: 0.6485 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6252 - accuracy: 0.7785 - val_loss: 0.9204 - val_accuracy: 0.6550 - lr: 1.0000e-04 - 25s/epoch - 992ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5422 - accuracy: 0.8050 - val_loss: 0.9185 - val_accuracy: 0.6697 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5113 - accuracy: 0.8152 - val_loss: 0.9226 - val_accuracy: 0.6712 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 21: early stopping
#
# ====== Batch 6 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.7994 - accuracy: 0.7149 - val_loss: 0.9031 - val_accuracy: 0.6758 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6837 - accuracy: 0.7487 - val_loss: 0.9149 - val_accuracy: 0.6887 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6839 - accuracy: 0.7473 - val_loss: 0.8669 - val_accuracy: 0.6838 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6950 - accuracy: 0.7528 - val_loss: 1.0716 - val_accuracy: 0.6364 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6279 - accuracy: 0.7668 - val_loss: 0.9443 - val_accuracy: 0.6822 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5545 - accuracy: 0.7994 - val_loss: 0.9519 - val_accuracy: 0.6731 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5718 - accuracy: 0.7919 - val_loss: 0.9918 - val_accuracy: 0.6690 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5563 - accuracy: 0.7971 - val_loss: 0.9483 - val_accuracy: 0.6817 - lr: 1.0000e-04 - 25s/epoch - 992ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4947 - accuracy: 0.8220 - val_loss: 1.0545 - val_accuracy: 0.6597 - lr: 1.0000e-04 - 25s/epoch - 992ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.6724 - accuracy: 0.7556 - val_loss: 1.0744 - val_accuracy: 0.6424 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5491 - accuracy: 0.8049 - val_loss: 1.1122 - val_accuracy: 0.6307 - lr: 1.0000e-04 - 25s/epoch - 992ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.5772 - accuracy: 0.7904 - val_loss: 1.0377 - val_accuracy: 0.6592 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4940 - accuracy: 0.8203 - val_loss: 1.0264 - val_accuracy: 0.6575 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4497 - accuracy: 0.8377 - val_loss: 1.0861 - val_accuracy: 0.6687 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4492 - accuracy: 0.8428 - val_loss: 1.0812 - val_accuracy: 0.6709 - lr: 1.0000e-04 - 25s/epoch - 991ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4539 - accuracy: 0.8449 - val_loss: 1.1431 - val_accuracy: 0.6565 - lr: 1.0000e-04 - 25s/epoch - 992ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.4046 - accuracy: 0.8640 - val_loss: 1.1054 - val_accuracy: 0.6837 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.3769 - accuracy: 0.8706 - val_loss: 1.0808 - val_accuracy: 0.6877 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 18: early stopping
#
# ====== Batch 7 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.9386 - accuracy: 0.6762 - val_loss: 0.9666 - val_accuracy: 0.6323 - lr: 1.0000e-04 - 25s/epoch - 1s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.9177 - accuracy: 0.6664 - val_loss: 1.0082 - val_accuracy: 0.6181 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.80213
# 25/25 - 25s - loss: 0.8290 - accuracy: 0.6832 - val_loss: 0.8485 - val_accuracy: 0.6913 - lr: 1.0000e-04 - 25s/epoch - 987ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 0.80213 to 0.76671, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.7722 - accuracy: 0.7094 - val_loss: 0.7667 - val_accuracy: 0.7348 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.6495 - accuracy: 0.7637 - val_loss: 0.7741 - val_accuracy: 0.7200 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.5916 - accuracy: 0.7830 - val_loss: 0.7902 - val_accuracy: 0.7386 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.6220 - accuracy: 0.7752 - val_loss: 0.8040 - val_accuracy: 0.7036 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.6017 - accuracy: 0.7816 - val_loss: 0.8384 - val_accuracy: 0.7178 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.5793 - accuracy: 0.7933 - val_loss: 0.9333 - val_accuracy: 0.7087 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.76671
# 25/25 - 25s - loss: 0.4892 - accuracy: 0.8254 - val_loss: 0.8345 - val_accuracy: 0.7451 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss improved from 0.76671 to 0.74529, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.5100 - accuracy: 0.8219 - val_loss: 0.7453 - val_accuracy: 0.7575 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4942 - accuracy: 0.8227 - val_loss: 0.8090 - val_accuracy: 0.7443 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4668 - accuracy: 0.8308 - val_loss: 0.8503 - val_accuracy: 0.7486 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4173 - accuracy: 0.8561 - val_loss: 0.8541 - val_accuracy: 0.7577 - lr: 1.0000e-04 - 25s/epoch - 990ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3913 - accuracy: 0.8676 - val_loss: 0.8066 - val_accuracy: 0.7589 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.5203 - accuracy: 0.8119 - val_loss: 1.0286 - val_accuracy: 0.6652 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4843 - accuracy: 0.8266 - val_loss: 0.8595 - val_accuracy: 0.7334 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4723 - accuracy: 0.8319 - val_loss: 0.9296 - val_accuracy: 0.6836 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.4889 - accuracy: 0.8218 - val_loss: 0.8495 - val_accuracy: 0.7332 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3636 - accuracy: 0.8787 - val_loss: 1.0032 - val_accuracy: 0.7091 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3867 - accuracy: 0.8645 - val_loss: 0.9453 - val_accuracy: 0.7220 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3184 - accuracy: 0.8907 - val_loss: 1.0237 - val_accuracy: 0.6939 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3467 - accuracy: 0.8755 - val_loss: 0.9904 - val_accuracy: 0.7235 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.3265 - accuracy: 0.8817 - val_loss: 0.8364 - val_accuracy: 0.7647 - lr: 1.0000e-04 - 25s/epoch - 988ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.2692 - accuracy: 0.9073 - val_loss: 0.9824 - val_accuracy: 0.7437 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.2731 - accuracy: 0.9087 - val_loss: 1.0888 - val_accuracy: 0.7145 - lr: 1.0000e-04 - 25s/epoch - 989ms/step
# Epoch 26: early stopping
#
# ====== Batch 8 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 1.0343 - accuracy: 0.6602 - val_loss: 1.0349 - val_accuracy: 0.6142 - lr: 1.0000e-04 - 25s/epoch - 994ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.8350 - accuracy: 0.6950 - val_loss: 0.9421 - val_accuracy: 0.6592 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.7406 - accuracy: 0.7369 - val_loss: 0.8710 - val_accuracy: 0.6905 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.7129 - accuracy: 0.7275 - val_loss: 0.7987 - val_accuracy: 0.7131 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.6290 - accuracy: 0.7686 - val_loss: 0.7947 - val_accuracy: 0.7329 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.74529
# 25/25 - 25s - loss: 0.5670 - accuracy: 0.7917 - val_loss: 0.7754 - val_accuracy: 0.7280 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 0.74529 to 0.72539, saving model to /tf/Notebooks/Iwashita/Output/Weights/augmented_tunet_tl_split_exp2_batch2_epoch1000_lr0.0001_p15_f0.1.h5
# 25/25 - 26s - loss: 0.5542 - accuracy: 0.7945 - val_loss: 0.7254 - val_accuracy: 0.7416 - lr: 1.0000e-04 - 26s/epoch - 1s/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5740 - accuracy: 0.7877 - val_loss: 0.8034 - val_accuracy: 0.7190 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5448 - accuracy: 0.8026 - val_loss: 0.7754 - val_accuracy: 0.7197 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5030 - accuracy: 0.8174 - val_loss: 0.9011 - val_accuracy: 0.6936 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6784 - accuracy: 0.7413 - val_loss: 1.0509 - val_accuracy: 0.6430 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6744 - accuracy: 0.7695 - val_loss: 0.8099 - val_accuracy: 0.7016 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5584 - accuracy: 0.7948 - val_loss: 0.9265 - val_accuracy: 0.6919 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4593 - accuracy: 0.8324 - val_loss: 0.8199 - val_accuracy: 0.7201 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4038 - accuracy: 0.8535 - val_loss: 0.7696 - val_accuracy: 0.7385 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3814 - accuracy: 0.8591 - val_loss: 0.9458 - val_accuracy: 0.7090 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4081 - accuracy: 0.8493 - val_loss: 0.8043 - val_accuracy: 0.7198 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4640 - accuracy: 0.8289 - val_loss: 0.8888 - val_accuracy: 0.7060 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4169 - accuracy: 0.8478 - val_loss: 0.7611 - val_accuracy: 0.7395 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3509 - accuracy: 0.8777 - val_loss: 0.7624 - val_accuracy: 0.7487 - lr: 1.0000e-04 - 25s/epoch - 986ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3029 - accuracy: 0.8960 - val_loss: 0.7454 - val_accuracy: 0.7603 - lr: 1.0000e-04 - 25s/epoch - 986ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2810 - accuracy: 0.9023 - val_loss: 0.8024 - val_accuracy: 0.7491 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 22: early stopping
#
# ====== Batch 9 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.9895 - accuracy: 0.6666 - val_loss: 1.1445 - val_accuracy: 0.5835 - lr: 1.0000e-04 - 25s/epoch - 998ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.8228 - accuracy: 0.7020 - val_loss: 1.1748 - val_accuracy: 0.6337 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.7487 - accuracy: 0.7203 - val_loss: 1.0737 - val_accuracy: 0.6389 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6645 - accuracy: 0.7629 - val_loss: 0.9653 - val_accuracy: 0.6662 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6149 - accuracy: 0.7766 - val_loss: 1.0982 - val_accuracy: 0.6104 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.7564 - accuracy: 0.7312 - val_loss: 1.1314 - val_accuracy: 0.6013 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6354 - accuracy: 0.7655 - val_loss: 1.0443 - val_accuracy: 0.6371 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5455 - accuracy: 0.8024 - val_loss: 1.1408 - val_accuracy: 0.6151 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4636 - accuracy: 0.8395 - val_loss: 1.0502 - val_accuracy: 0.6446 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4548 - accuracy: 0.8397 - val_loss: 1.2104 - val_accuracy: 0.6358 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4502 - accuracy: 0.8460 - val_loss: 1.3589 - val_accuracy: 0.6306 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4914 - accuracy: 0.8271 - val_loss: 1.2303 - val_accuracy: 0.6238 - lr: 1.0000e-04 - 25s/epoch - 985ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6558 - accuracy: 0.7578 - val_loss: 1.1544 - val_accuracy: 0.6186 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4730 - accuracy: 0.8329 - val_loss: 1.1141 - val_accuracy: 0.6396 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3690 - accuracy: 0.8688 - val_loss: 1.2981 - val_accuracy: 0.6364 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3185 - accuracy: 0.8879 - val_loss: 1.3064 - val_accuracy: 0.6228 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2614 - accuracy: 0.9112 - val_loss: 1.4177 - val_accuracy: 0.6470 - lr: 1.0000e-04 - 25s/epoch - 984ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2408 - accuracy: 0.9191 - val_loss: 1.4467 - val_accuracy: 0.6354 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2452 - accuracy: 0.9162 - val_loss: 1.4172 - val_accuracy: 0.6343 - lr: 1.0000e-04 - 25s/epoch - 983ms/step
# Epoch 19: early stopping
#
# ====== Batch 10 ======
#
# Epoch 1/1000
#
# Epoch 1: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.9411 - accuracy: 0.6686 - val_loss: 1.0547 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 25s/epoch - 995ms/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.6721 - accuracy: 0.7595 - val_loss: 0.9732 - val_accuracy: 0.6631 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5542 - accuracy: 0.7944 - val_loss: 0.9374 - val_accuracy: 0.6639 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5055 - accuracy: 0.8156 - val_loss: 1.0220 - val_accuracy: 0.6592 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.5555 - accuracy: 0.7991 - val_loss: 0.8850 - val_accuracy: 0.6813 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4697 - accuracy: 0.8189 - val_loss: 0.9044 - val_accuracy: 0.7135 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4176 - accuracy: 0.8438 - val_loss: 0.8456 - val_accuracy: 0.7355 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4385 - accuracy: 0.8406 - val_loss: 0.8299 - val_accuracy: 0.7291 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.4665 - accuracy: 0.8203 - val_loss: 0.8862 - val_accuracy: 0.7053 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3536 - accuracy: 0.8735 - val_loss: 0.8044 - val_accuracy: 0.7629 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.3315 - accuracy: 0.8801 - val_loss: 0.8801 - val_accuracy: 0.7321 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2961 - accuracy: 0.8963 - val_loss: 0.8335 - val_accuracy: 0.7563 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2545 - accuracy: 0.9114 - val_loss: 0.9527 - val_accuracy: 0.7486 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2210 - accuracy: 0.9257 - val_loss: 0.9638 - val_accuracy: 0.7561 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2380 - accuracy: 0.9165 - val_loss: 1.0365 - val_accuracy: 0.7341 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2034 - accuracy: 0.9309 - val_loss: 1.0325 - val_accuracy: 0.7592 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1973 - accuracy: 0.9313 - val_loss: 1.0549 - val_accuracy: 0.7566 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2009 - accuracy: 0.9301 - val_loss: 0.9409 - val_accuracy: 0.7759 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1905 - accuracy: 0.9361 - val_loss: 1.0353 - val_accuracy: 0.7526 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1707 - accuracy: 0.9430 - val_loss: 1.0362 - val_accuracy: 0.7674 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1678 - accuracy: 0.9422 - val_loss: 1.1102 - val_accuracy: 0.7599 - lr: 1.0000e-04 - 25s/epoch - 982ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1746 - accuracy: 0.9399 - val_loss: 1.1430 - val_accuracy: 0.7313 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1734 - accuracy: 0.9402 - val_loss: 1.0998 - val_accuracy: 0.7569 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.1616 - accuracy: 0.9448 - val_loss: 1.2284 - val_accuracy: 0.6978 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 0.72539
# 25/25 - 25s - loss: 0.2083 - accuracy: 0.9321 - val_loss: 1.0448 - val_accuracy: 0.7549 - lr: 1.0000e-04 - 25s/epoch - 981ms/step
# Epoch 25: early stopping
# Done

# %%
score = TUNet_Score(
    exp2_model, 
    os.path.join(WEIGHTS_PATH, EXP2_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP2_FILENAME + '.txt'),
    exp2_rgb_X_test,
    exp2_ir_X_test,
    exp2_y_test)
# Out:
# 124/124 [==============================] - 28s 223ms/step - loss: 0.7914 - accuracy: 0.7237
# Test loss: 0.791431188583374
# Test accuracy: 0.7236757278442383

# %%
y_pred = TUNet_Predict(exp2_model, exp2_rgb_X_test, exp2_ir_X_test)
# Out:
# 124/124 [==============================] - 28s 221ms/step
# 2023-08-21 17:52:38.744078: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 2271965696 exceeds 10% of free system memory.

# %%
TUNet_Display(exp2_rgb_X_test, exp2_ir_X_test, exp2_y_test, y_pred)

# %%
TUNet_Metrics(exp2_y_test, y_pred, os.path.join(METRICS_PATH, EXP2_FILENAME + '.txt'))
# Out:
# Mean IoU: 0.4692488180602639
# Pixel accuracy: 0.7236757328223322
# Mean accuracy: 0.6102844734351731
# Frequency-Weighted IoU: 0.7013973679930443
