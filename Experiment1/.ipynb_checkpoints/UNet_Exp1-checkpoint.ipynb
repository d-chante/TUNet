# %% [markdown]
# # UNet

# %%
'''
IMPORTS
'''
import tensorflow as tf
from tensorflow.image import resize, ResizeMethod

import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

import random
import os
import time
from numpy import load
import numpy as np
import matplotlib.pyplot as plt

'''
DATA PATHS
'''
TOP_DIR = '/tf/Notebooks/Iwashita'

TRAIN_DIR = TOP_DIR + '/Data/Preprocessed/Experiment1/Train'
VAL_DIR = TOP_DIR + '/Data/Preprocessed/Experiment1/Validate'
TEST_DIR = TOP_DIR + '/Data/Preprocessed/Experiment1/Test'

'''
OUTPUTS PATH
'''
WEIGHTS_PATH = TOP_DIR + '/Output/Weights/'
METRICS_PATH = TOP_DIR + '/Output/Metrics/'

'''
GPU
'''
gpu_p40 = '/device:GPU:1'
gpu_1660 = '/device:GPU:0'

# !nvidia-smi

'''
TRAINING DATA
'''
print(TRAIN_DIR)
# !cd /tf/Notebooks/Iwashita/Data/Preprocessed/Experiment1/Train && ls

exp1_rgb_X_train = load(TRAIN_DIR + '/exp1_rgb_X_train.npy')
exp1_ir_X_train = load(TRAIN_DIR + '/exp1_ir_X_train.npy')
exp1_y_train = load(TRAIN_DIR + '/exp1_y_train.npy')

'''
VALIDATION DATA
'''
exp1_rgb_X_val = load(VAL_DIR + '/exp1_rgb_X_val.npy')
exp1_ir_X_val = load(VAL_DIR + '/exp1_ir_X_val.npy')
exp1_y_val =load(VAL_DIR + '/exp1_y_val.npy')

'''
TEST DATA
'''
exp1_rgb_X_test = load(TEST_DIR + '/exp1_rgb_X_test.npy')
exp1_ir_X_test = load(TEST_DIR + '/exp1_ir_X_test.npy')
exp1_y_test =load(TEST_DIR + '/exp1_y_test.npy')

'''
INTERSECTION OVER UNION
'''
def iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union

    return iou, np.mean(np.diag(iou))

'''
PIXEL ACCURACY
'''
def pixel_accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / y_true.size

'''
MEAN ACCURACY
'''
def mean_accuracy(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]

    area_true[area_true == 0] = 1e-9
    accuracy = np.diag(intersection) / area_true

    return np.mean(accuracy)

'''
FIRM-WEIGHT INTERSECTION OVER UNION
'''
def fw_iou(y_true, y_pred, num_classes):
    intersection = np.histogram2d(y_true.flatten(), y_pred.flatten(), bins=num_classes)[0]
    area_true = np.histogram(y_true, bins=num_classes)[0]
    area_pred = np.histogram(y_pred, bins=num_classes)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    union = area_true + area_pred - intersection

    union[union == 0] = 1e-9
    iou = intersection / union
    fw_iou = np.sum(area_true * iou) / np.sum(area_true)

    return fw_iou

def display_one_hot_annotation(annotations_onehot, num_classes):
    label = np.argmax(annotations_onehot, axis=-1)
    cmap = plt.get_cmap('tab10', num_classes)

    plt.imshow(label, cmap=cmap)
    plt.colorbar(ticks=range(num_classes), format=plt.FuncFormatter(lambda val, loc: {
        0: "unlabeled",
        1: "sand",
        2: "soil",
        3: "ballast",
        4: "rock",
        5: "bedrock",
        6: "rocky terrain"
    }[val]))
    plt.show()
    
'''
CALCULATE METRICS
'''
def UNet_Metrics(y_test, y_pred, metrics_filename):
    y_pred_classes = np.argmax(y_pred, axis=-1)
    y_true_classes = np.argmax(y_test, axis=-1)
    
    num_classes = 7
    
    iou_values, mean_iou = iou(y_true_classes, y_pred_classes, num_classes)
    pixel_acc = pixel_accuracy(y_true_classes, y_pred_classes)
    mean_acc = mean_accuracy(y_true_classes, y_pred_classes, num_classes)
    fw_iou_value = fw_iou(y_true_classes, y_pred_classes, num_classes)

    print(f"Mean IoU: {mean_iou}")
    print(f"Pixel accuracy: {pixel_acc}")
    print(f"Mean accuracy: {mean_acc}")
    print(f"Frequency-Weighted IoU: {fw_iou_value}")
    
    with open(metrics_filename, "a") as f:
        f.write("\nIoU Values:\n")
        
        for i, iou_val in enumerate(iou_values):
            f.write(f"Class {i}: {iou_val}\n")
        f.write(f"\nMean IoU: {mean_iou}\n")
        f.write(f"Pixel Accuracy: {pixel_acc}\n")
        f.write(f"Mean Accuracy: {mean_acc}\n")
        f.write(f"Frequency Weighted IoU: {fw_iou_value}\n")

print("Done")
# Out:
# 2023-07-15 01:11:15.509288: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Sat Jul 15 01:11:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.125.06   Driver Version: 525.125.06   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P40           Off  | 00000000:05:00.0 Off |                  Off |
# | N/A   45C    P8    10W / 250W |      4MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0  On |                  N/A |
# | 44%   43C    P5    18W / 125W |    772MiB /  6144MiB |     26%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# /tf/Notebooks/Iwashita/Data/Preprocessed/Experiment1/Train
# exp1_ir_X_train.npy  exp1_rgb_X_train.npy  exp1_y_train.npy
# Done

# %%
'''
MODEL PARAMS
'''
RGB_DIM = (572, 572, 3)
IR_DIM = (572, 572)
ANNOTATION_DIM = (572, 572, 7)

NUM_CLASSES = 7

BATCH_SIZE = 4 #2
EPOCHS = 100  #100

LEARNING_RATE = 1e-4 #1e-4
PATIENCE = 10 #15
FACTOR = 0.1 #0.1

EXP1_FILENAME = "unet_exp1_batch{}_epoch{}_lr{}_p{}_f{}".format(
    BATCH_SIZE, EPOCHS, LEARNING_RATE, PATIENCE, FACTOR)

print("Done")
# Out:
# Done

# %% [markdown]
# ### T/UNet Common

# %%
'''
MODEL
'''
def ContractionPath(inputs, _padding='same', _activation='relu'):
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    c1 = Conv2D(64, (3, 3), activation="relu", padding="same")(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(0.25)(p1)

    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(p1)
    c2 = Conv2D(128, (3, 3), activation="relu", padding="same")(c2)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(0.5)(p2)

    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(p2)
    c3 = Conv2D(256, (3, 3), activation="relu", padding="same")(c3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(0.5)(p3)

    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(p3)
    c4 = Conv2D(512, (3, 3), activation="relu", padding="same")(c4)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(0.5)(p4)
    
    '''
    RETURN
    '''
    return c1, c2, c3, c4, p4

def ExpansionPath(c1, c2, c3, c4, p4, _padding='same', _activation='relu'):    
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(p4)
    cm = Conv2D(1024, (3, 3), activation="relu", padding="same")(cm)
    
    deconv4 = Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(cm)
    c4 = resize(c4, (deconv4.shape[1], deconv4.shape[2]), method=ResizeMethod.BILINEAR)
    uconv4 = concatenate([deconv4, c4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(512, (3, 3), activation="relu", padding="same")(uconv4)

    deconv3 = Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(uconv4)
    c3 = resize(c3, (deconv3.shape[1], deconv3.shape[2]), method=ResizeMethod.BILINEAR)
    uconv3 = concatenate([deconv3, c3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(256, (3, 3), activation="relu", padding="same")(uconv3)

    deconv2 = Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(uconv3)
    c2 = resize(c2, (deconv2.shape[1], deconv2.shape[2]), method=ResizeMethod.BILINEAR)
    uconv2 = concatenate([deconv2, c2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(128, (3, 3), activation="relu", padding="same")(uconv2)

    deconv1 = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(uconv2)
    c1 = resize(c1, (deconv1.shape[1], deconv1.shape[2]), method=ResizeMethod.BILINEAR)
    uconv1 = concatenate([deconv1, c1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(64, (3, 3), activation="relu", padding="same")(uconv1)
    
    return uconv1

def UNet(input_dim):
    '''
    INPUT
    '''
    #inputs = Input((input_dim), name='img')
    inputs = Input((input_dim))
    '''
    CONTRACTION PATH
    '''
    c1, c2, c3, c4, p4 = ContractionPath(inputs)

    '''
    EXPANSION PATH
    '''
    cout = ExpansionPath(c1, c2, c3, c4, p4)

    '''
    OUTPUT
    '''
    outputs = Conv2D(7, (1, 1), padding="same", activation='softmax')(cout)
    outputs = resize(outputs, (572, 572), method=ResizeMethod.BILINEAR)

    '''
    RETURN
    '''
    return Model(inputs, outputs)

'''
TRAIN
'''
def UNet_Train(model, weights_filename, 
               X_rgb_train, y_train, 
               X_rgb_val, y_val):

    try:
        with tf.device(gpu_p40):
            
            model.compile(
                optimizer=Adam(learning_rate=LEARNING_RATE), 
                loss='categorical_crossentropy', 
                metrics=['accuracy'])

            callbacks = [
                ModelCheckpoint(weights_filename, save_best_only=True, save_weights_only=True, verbose=1),
                EarlyStopping(patience=PATIENCE, verbose=1),
                ReduceLROnPlateau(factor=FACTOR, patience=PATIENCE, min_lr=LEARNING_RATE, verbose=1)]
    
            history = model.fit(
                [X_rgb_train], y_train,
                validation_data=([X_rgb_val], y_val),
                batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callbacks, verbose=2)
        
    except RuntimeError as e:
        print(e)
        
'''
SCORE
'''
def UNet_Score(model, weights_filename, metrics_filename, 
                X_rgb_test, y_test):
    
    try:
        with tf.device(gpu_p40):
            model.load_weights(weights_filename)

            score = model.evaluate([X_rgb_test], y_test, verbose=0)

            print("Test loss:", score[0])
            print("Test accuracy:", score[1])

            with open(metrics_filename, "a") as f:
                f.write(f"\Test Loss: {score[0]}\n")
                f.write(f"\Test Accuracy: {score[1]}\n")
                
    except RuntimeError as e:
        print(e)

'''
PREDICT
'''
def UNet_Predict(model, X_rgb_test):
    try:
        with tf.device(gpu_p40):
            pred = model.predict([X_rgb_test])
            
    except RuntimeError as e:
        print(e)
        
    return pred

'''
DISPLAY RANDOM RESULT
'''
def UNet_Display(X_rgb_test, y_test, y_pred):
    fig, axes = plt.subplots(1, 3, figsize=(10, 6))
    n = random.randint(0, len(X_rgb_test)-1)
    cmap = plt.get_cmap('tab10', 7)
    
    axes[0].imshow(X_rgb_test[n])
    axes[1].imshow(np.argmax(y_test[n], axis=-1), cmap=cmap)
    axes[2].imshow(np.argmax(y_pred[n], axis=-1), cmap=cmap)
                                           
    axes[0].set_title("RGB")
    axes[1].set_title("Annotation")
    axes[2].set_title("Predicted")
    
    for ax in axes.flatten():
        ax.axis("off")
        
    plt.tight_layout()
    plt.show()
    
print("Done")
# Out:
# Done

# %%
exp1_model = UNet(RGB_DIM)

UNet_Train(exp1_model, os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'), 
                exp1_rgb_X_train, exp1_y_train,
                exp1_rgb_X_val, exp1_y_val)
# Out:
# 2023-07-15 01:11:37.942792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:37.943096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:37.948661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:37.949008: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:37.949309: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:37.949608: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.129885: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.130105: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.130295: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.130474: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.130661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:38.130840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.049269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.049501: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.049704: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.049891: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.050074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.050243: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3828 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:06:00.0, compute capability: 7.5
# 2023-07-15 01:11:39.050517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-15 01:11:39.050683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 23630 MB memory:  -> device: 1, name: Tesla P40, pci bus id: 0000:05:00.0, compute capability: 6.1
# Epoch 1/100
# 2023-07-15 01:11:40.953471: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-07-15 01:11:41.669951: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# Epoch 1: val_loss improved from inf to 1.84471, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 38s - loss: 1.9110 - accuracy: 0.2678 - val_loss: 1.8447 - val_accuracy: 0.6347 - lr: 1.0000e-04 - 38s/epoch - 5s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.84471 to 1.30599, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.4500 - accuracy: 0.6157 - val_loss: 1.3060 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 1.30599
# 7/7 - 8s - loss: 1.7429 - accuracy: 0.6159 - val_loss: 1.6839 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 1.30599
# 7/7 - 8s - loss: 1.5782 - accuracy: 0.6159 - val_loss: 1.6006 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 1.30599
# 7/7 - 8s - loss: 1.4239 - accuracy: 0.6158 - val_loss: 1.3864 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.30599 to 1.30226, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.3427 - accuracy: 0.6158 - val_loss: 1.3023 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 1.30226
# 7/7 - 8s - loss: 1.3141 - accuracy: 0.6159 - val_loss: 1.3397 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 1.30226
# 7/7 - 8s - loss: 1.3302 - accuracy: 0.6159 - val_loss: 1.3613 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 1.30226 to 1.29759, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.3205 - accuracy: 0.6159 - val_loss: 1.2976 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.29759
# 7/7 - 8s - loss: 1.3027 - accuracy: 0.6159 - val_loss: 1.3078 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.29759
# 7/7 - 8s - loss: 1.3003 - accuracy: 0.6159 - val_loss: 1.3407 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.29759
# 7/7 - 8s - loss: 1.3006 - accuracy: 0.6159 - val_loss: 1.3160 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 1.29759 to 1.27907, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.3074 - accuracy: 0.6159 - val_loss: 1.2791 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.27907
# 7/7 - 8s - loss: 1.2954 - accuracy: 0.6159 - val_loss: 1.3059 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.27907
# 7/7 - 8s - loss: 1.2918 - accuracy: 0.6159 - val_loss: 1.2916 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 1.27907
# 7/7 - 8s - loss: 1.2821 - accuracy: 0.6159 - val_loss: 1.2810 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 1.27907 to 1.26902, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2797 - accuracy: 0.6159 - val_loss: 1.2690 - val_accuracy: 0.6350 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.26902
# 7/7 - 8s - loss: 1.2705 - accuracy: 0.6159 - val_loss: 1.2772 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 1.26902
# 7/7 - 8s - loss: 1.3127 - accuracy: 0.6159 - val_loss: 1.2943 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 1.26902 to 1.24550, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.3126 - accuracy: 0.6159 - val_loss: 1.2455 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 1.24550
# 7/7 - 8s - loss: 1.2755 - accuracy: 0.6159 - val_loss: 1.2758 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 1.24550
# 7/7 - 8s - loss: 1.2659 - accuracy: 0.6159 - val_loss: 1.2644 - val_accuracy: 0.6351 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 1.24550 to 1.23670, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2547 - accuracy: 0.6160 - val_loss: 1.2367 - val_accuracy: 0.6352 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 1.23670 to 1.23456, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2527 - accuracy: 0.6160 - val_loss: 1.2346 - val_accuracy: 0.6353 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 1.23456 to 1.21872, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2354 - accuracy: 0.6164 - val_loss: 1.2187 - val_accuracy: 0.6356 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 1.21872 to 1.20890, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2288 - accuracy: 0.6164 - val_loss: 1.2089 - val_accuracy: 0.6360 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 1.20890 to 1.16218, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.2037 - accuracy: 0.6173 - val_loss: 1.1622 - val_accuracy: 0.6362 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 1.16218 to 1.12557, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.1703 - accuracy: 0.6176 - val_loss: 1.1256 - val_accuracy: 0.6370 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 1.12557 to 1.10898, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.1359 - accuracy: 0.6192 - val_loss: 1.1090 - val_accuracy: 0.6391 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 1.10898
# 7/7 - 8s - loss: 1.1221 - accuracy: 0.6256 - val_loss: 1.1157 - val_accuracy: 0.6419 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 1.10898 to 1.10352, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.1177 - accuracy: 0.6508 - val_loss: 1.1035 - val_accuracy: 0.6877 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 1.10352 to 1.05497, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.0772 - accuracy: 0.6737 - val_loss: 1.0550 - val_accuracy: 0.6900 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.0775 - accuracy: 0.6758 - val_loss: 1.0867 - val_accuracy: 0.6732 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.1222 - accuracy: 0.6659 - val_loss: 1.0913 - val_accuracy: 0.6816 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.1607 - accuracy: 0.6486 - val_loss: 1.1943 - val_accuracy: 0.6802 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.1296 - accuracy: 0.6636 - val_loss: 1.1172 - val_accuracy: 0.6634 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.1088 - accuracy: 0.6616 - val_loss: 1.0844 - val_accuracy: 0.6895 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.1015 - accuracy: 0.6578 - val_loss: 1.0802 - val_accuracy: 0.6856 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.0965 - accuracy: 0.6607 - val_loss: 1.0792 - val_accuracy: 0.6782 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 1.05497
# 7/7 - 8s - loss: 1.0577 - accuracy: 0.6660 - val_loss: 1.0630 - val_accuracy: 0.6873 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 1.05497 to 1.03870, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.0045 - accuracy: 0.6836 - val_loss: 1.0387 - val_accuracy: 0.6926 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 1.03870
# 7/7 - 8s - loss: 1.0090 - accuracy: 0.6788 - val_loss: 1.0647 - val_accuracy: 0.6876 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 43/100
#
# Epoch 43: val_loss improved from 1.03870 to 1.02148, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 1.0078 - accuracy: 0.6844 - val_loss: 1.0215 - val_accuracy: 0.6923 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 44/100
#
# Epoch 44: val_loss improved from 1.02148 to 1.01961, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9961 - accuracy: 0.6802 - val_loss: 1.0196 - val_accuracy: 0.6942 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 1.01961
# 7/7 - 8s - loss: 1.0012 - accuracy: 0.6838 - val_loss: 1.0442 - val_accuracy: 0.6928 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 1.01961
# 7/7 - 8s - loss: 1.0606 - accuracy: 0.6706 - val_loss: 1.1142 - val_accuracy: 0.6687 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 1.01961
# 7/7 - 8s - loss: 1.0595 - accuracy: 0.6588 - val_loss: 1.0292 - val_accuracy: 0.6944 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 48/100
#
# Epoch 48: val_loss improved from 1.01961 to 1.01881, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9800 - accuracy: 0.6816 - val_loss: 1.0188 - val_accuracy: 0.6924 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 1.01881 to 1.01839, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9758 - accuracy: 0.6857 - val_loss: 1.0184 - val_accuracy: 0.6898 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 50/100
#
# Epoch 50: val_loss improved from 1.01839 to 0.99108, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9914 - accuracy: 0.6789 - val_loss: 0.9911 - val_accuracy: 0.6959 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 51/100
#
# Epoch 51: val_loss improved from 0.99108 to 0.99041, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9452 - accuracy: 0.6839 - val_loss: 0.9904 - val_accuracy: 0.6966 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.99041
# 7/7 - 8s - loss: 1.0021 - accuracy: 0.6854 - val_loss: 0.9933 - val_accuracy: 0.6972 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.99041
# 7/7 - 8s - loss: 0.9664 - accuracy: 0.6875 - val_loss: 1.0130 - val_accuracy: 0.6969 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.99041 to 0.98153, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9614 - accuracy: 0.6885 - val_loss: 0.9815 - val_accuracy: 0.6986 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.98153
# 7/7 - 8s - loss: 0.9383 - accuracy: 0.6858 - val_loss: 0.9839 - val_accuracy: 0.6949 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 56/100
#
# Epoch 56: val_loss improved from 0.98153 to 0.96967, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9360 - accuracy: 0.6839 - val_loss: 0.9697 - val_accuracy: 0.6982 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.96967 to 0.95228, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9466 - accuracy: 0.6868 - val_loss: 0.9523 - val_accuracy: 0.6982 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9750 - accuracy: 0.6832 - val_loss: 1.0127 - val_accuracy: 0.6903 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9735 - accuracy: 0.6782 - val_loss: 0.9687 - val_accuracy: 0.6953 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9398 - accuracy: 0.6893 - val_loss: 1.0173 - val_accuracy: 0.6917 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9379 - accuracy: 0.6889 - val_loss: 1.0020 - val_accuracy: 0.6906 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9495 - accuracy: 0.6831 - val_loss: 0.9673 - val_accuracy: 0.6957 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9674 - accuracy: 0.6789 - val_loss: 0.9624 - val_accuracy: 0.6970 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9409 - accuracy: 0.6892 - val_loss: 0.9855 - val_accuracy: 0.6972 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.95228
# 7/7 - 8s - loss: 0.9149 - accuracy: 0.6913 - val_loss: 0.9736 - val_accuracy: 0.6951 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 0.95228 to 0.93644, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.9080 - accuracy: 0.6922 - val_loss: 0.9364 - val_accuracy: 0.7023 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.93644
# 7/7 - 8s - loss: 0.8988 - accuracy: 0.6930 - val_loss: 0.9366 - val_accuracy: 0.6988 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 68/100
#
# Epoch 68: val_loss improved from 0.93644 to 0.92864, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.8838 - accuracy: 0.6965 - val_loss: 0.9286 - val_accuracy: 0.7038 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.92864
# 7/7 - 8s - loss: 0.8969 - accuracy: 0.6954 - val_loss: 0.9345 - val_accuracy: 0.6982 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.92864
# 7/7 - 8s - loss: 0.8909 - accuracy: 0.6969 - val_loss: 0.9295 - val_accuracy: 0.7013 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 71/100
#
# Epoch 71: val_loss improved from 0.92864 to 0.92796, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.8784 - accuracy: 0.7012 - val_loss: 0.9280 - val_accuracy: 0.6953 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 72/100
#
# Epoch 72: val_loss improved from 0.92796 to 0.91563, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.8712 - accuracy: 0.7029 - val_loss: 0.9156 - val_accuracy: 0.6968 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.91563
# 7/7 - 8s - loss: 0.8574 - accuracy: 0.7095 - val_loss: 0.9243 - val_accuracy: 0.6879 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.91563 to 0.91496, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.8956 - accuracy: 0.7038 - val_loss: 0.9150 - val_accuracy: 0.6992 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.91496
# 7/7 - 8s - loss: 0.8845 - accuracy: 0.7095 - val_loss: 0.9376 - val_accuracy: 0.6794 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 76/100
#
# Epoch 76: val_loss improved from 0.91496 to 0.89074, saving model to /tf/Notebooks/Iwashita/Output/Weights/unet_exp1_batch4_epoch100_lr0.0001_p10_f0.1.h5
# 7/7 - 9s - loss: 0.8706 - accuracy: 0.7069 - val_loss: 0.8907 - val_accuracy: 0.6961 - lr: 1.0000e-04 - 9s/epoch - 1s/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8763 - accuracy: 0.7068 - val_loss: 0.8939 - val_accuracy: 0.6968 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 1.0067 - accuracy: 0.6834 - val_loss: 1.0612 - val_accuracy: 0.6644 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 1.0601 - accuracy: 0.6532 - val_loss: 0.9916 - val_accuracy: 0.6863 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.9255 - accuracy: 0.7038 - val_loss: 0.9356 - val_accuracy: 0.6909 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8877 - accuracy: 0.7096 - val_loss: 0.8955 - val_accuracy: 0.6946 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8699 - accuracy: 0.7125 - val_loss: 0.9058 - val_accuracy: 0.6931 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8804 - accuracy: 0.7132 - val_loss: 0.9334 - val_accuracy: 0.6891 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8805 - accuracy: 0.7023 - val_loss: 0.9262 - val_accuracy: 0.6965 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8720 - accuracy: 0.7076 - val_loss: 0.9079 - val_accuracy: 0.6888 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.89074
# 7/7 - 8s - loss: 0.8571 - accuracy: 0.7124 - val_loss: 0.9022 - val_accuracy: 0.6908 - lr: 1.0000e-04 - 8s/epoch - 1s/step
# Epoch 86: early stopping

# %%
score = UNet_Score(
    exp1_model, 
    os.path.join(WEIGHTS_PATH, EXP1_FILENAME + '.h5'),
    os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'),
    exp1_rgb_X_test,
    exp1_y_test)
# Out:
# Test loss: 1.0332049131393433
# Test accuracy: 0.5751057267189026

# %%
y_pred = UNet_Predict(exp1_model, exp1_rgb_X_test)
# Out:
# 1/1 [==============================] - 1s 953ms/step

# %%
UNet_Display(exp1_rgb_X_test, exp1_y_test, y_pred)

# %%
UNet_Metrics(exp1_y_test, y_pred, os.path.join(METRICS_PATH, EXP1_FILENAME + '.txt'))
# Out:
# Mean IoU: 0.11776850926799949
# Pixel accuracy: 0.5751057038711692
# Mean accuracy: 0.2811287678401059
# Frequency-Weighted IoU: 0.4776539556498928
